# %% [markdown]
# # Week 2 Project

# %% [markdown]
# Once again, we’ll be using the [Women's Ecommerce Clothing Reviews Dataset from Kaggle](https://www.kaggle.com/datasets/nicapotato/womens-ecommerce-clothing-reviews), which Kaggle states is a
#
# > dataset revolving around the reviews written by customers. Its nine supportive features offer a great environment to parse out the text through its multiple dimensions. Because this is real commercial data, it has been anonymized, and references to the company in the review text and body have been replaced with “retailer”.
#
# The machine learning task will be sentiment analysis, classifying each review as having positive or negative sentiment.

# %% [markdown]
# ## Task 1: Training and Evaluating Sentiment Analysis Models Using Metaflow
#
# In this task, you'll use Metaflow to build two machine learning models for sentiment analysis: a baseline *"majority class"* classifier and your own custom model. You'll then train both models in parallel and experiment with different hyperparameters to optimize their performance. Finally, you'll use this notebook and the Metaflow Client API to analyze the results of your different models and hyperparameters. Here's what you'll need to do:
#
# ### Step 1: Build the Workflows
# The first step in this task is to build the workflow(s) for sentiment analysis using the Metaflow framework. Start by creating a new flow in Metaflow and implementing the baseline *"majority class"* classifier. Then, build your own custom classifier using techniques you learned in Week 1, or any [helpful resources](https://outerbounds.com/docs/nlp-tutorial-L2/) you'd like. For your custom model, be sure to include steps for data preprocessing, model training, and evaluation.
#
# ### Step 2: Train Both Models in Parallel
# Once you've built your models, the next step is to train both models in parallel using the Metaflow framework. Use Metaflow to run both training jobs in parallel steps. If you get stuck, you may want to review the [FlowSpec branching documentation](https://docs.metaflow.org/metaflow/basics#branch).
#
# ### Step 3: Experiment with Hyperparameters
# After you've trained both models in parallel, the next step is to experiment with different hyperparameters to optimize their performance. Try different values for hyperparameters such as learning rate, batch size, and number of epochs, and record the results for each combination of hyperparameters as Data Artifacts in Metaflow.
#
# ### Step 4: Analyze the Results
# Finally, use this notebook and the Metaflow Client API to analyze the results of your different models and hyperparameters. Create visualizations to compare the performance of the two models and identify the best hyperparameters for each one.
#
# By completing this task, you'll gain experience working with the Metaflow framework and learn how to build and optimize machine learning workflows for sentiment analysis.

# %%
from collections import Counter
import pandas as pd
import numpy as np 
from termcolor import colored
import matplotlib.pyplot as plt
import seaborn as sns
import string

# You can style your plots here, but it is not part of the project.
YELLOW = '#FFBC00'
GREEN = '#37795D'
PURPLE = '#5460C0'
BACKGROUND = '#F4EBE6'
colors = [GREEN, PURPLE]
custom_params = {
    'axes.spines.right': False, 'axes.spines.top': False,
    'axes.facecolor':BACKGROUND, 'figure.facecolor': BACKGROUND, 
    'figure.figsize':(8, 8)
}
sns_palette = sns.color_palette(colors, len(colors))
sns.set_theme(style='ticks', rc=custom_params)

# %%
import io
from sklearn.model_selection import train_test_split

# TODO: load the data. 
df = pd.read_csv("../data/Womens Clothing E-Commerce Reviews.csv")
labeling_function = lambda row: 1 if row['rating']>=4 else 0
# transformations
df.columns = ["_".join(name.lower().strip().split()) for name in df.columns]
df = df[~df.review_text.isna()]
df['review'] = df['review_text'].astype('str')
_has_review_df = df[df['review_text'] != 'nan']
reviews = _has_review_df['review_text']
labels = _has_review_df.apply(labeling_function, axis=1)
df = pd.DataFrame({'label': labels, **_has_review_df})

# split into training and validation.
_df = pd.DataFrame({'review': reviews, 'label': labels})
traindf, valdf = train_test_split(_df, test_size=0.2)

# %%
# TODO: build the majority class baseline model. 
# TODO: find the majority class in the labels. 🤔
# TODO: score the model on valdf with a 2D metric space: sklearn.metrics.accuracy_score, sklearn.metrics.roc_auc_score
    # Documentation on suggested model-scoring approach: https://scikit-learn.org/stable/modules/model_evaluation.html

import numpy as np
from sklearn.dummy import DummyClassifier
from sklearn.metrics import accuracy_score, roc_auc_score, confusion_matrix
np.random.seed(42)

dummy_clf = DummyClassifier(strategy="most_frequent")
dummy_clf.fit(traindf['review'], traindf['label'])

preds = dummy_clf.predict(valdf['review'])

base_acc = accuracy_score(valdf['label'], preds)
base_rocauc = roc_auc_score(valdf['label'], preds)

print("accuracy: " , base_acc)
print("ROC AUC: ", base_rocauc)
# Out:
# accuracy:  0.7756679178626629
# ROC AUC:  0.5

# %%
# %%writefile model.py
# TODO: modify this custom model to your liking. Check out this tutorial for more on this class: https://outerbounds.com/docs/nlp-tutorial-L2/
# TODO: train the model on traindf.
# TODO: score the model on valdf with _the same_ 2D metric space you used in previous cell.
# TODO: test your model works by importing the model module in notebook cells, and trying to fit traindf and score predictions on the valdf data!

import tensorflow as tf
from tensorflow.keras import layers, optimizers, regularizers
from sklearn.base import BaseEstimator, ClassifierMixin
from sklearn.metrics import accuracy_score, roc_auc_score
from sklearn.feature_extraction.text import CountVectorizer

class NbowModel():
    def __init__(self, vocab_sz):

        self.vocab_sz = vocab_sz

        # Instantiate the CountVectorizer
        self.cv = CountVectorizer(
            min_df=.005, max_df = .75, stop_words='english', 
            strip_accents='ascii', max_features=self.vocab_sz
        )

        # Define the keras model
        inputs = tf.keras.Input(shape=(self.vocab_sz,), 
                                name='input')
        x = layers.Dropout(0.10)(inputs)
        x = layers.Dense(
            15, activation="relu",
            kernel_regularizer=regularizers.L1L2(l1=1e-5, l2=1e-4)
        )(x)
        predictions = layers.Dense(1, activation="sigmoid",)(x)
        self.model = tf.keras.Model(inputs, predictions)
        opt = optimizers.Adam(learning_rate=0.002)
        self.model.compile(loss="binary_crossentropy", 
                           optimizer=opt, metrics=["accuracy"])

    def fit(self, X, y):
        print(X.shape)
        print(X[0])
        res = self.cv.fit_transform(X).toarray()
        self.model.fit(x=res, y=y, batch_size=32, 
                       epochs=10, validation_split=.2)
    
    def predict(self, X):
        print(X.shape)
        print(X[0])
        res = self.cv.transform(X).toarray()
        return self.model.predict(res)
    
    def eval_acc(self, X, labels, threshold=.5):
        return accuracy_score(labels, 
                              self.predict(X) > threshold)
    
    def eval_rocauc(self, X, labels):
        return roc_auc_score(labels,  self.predict(X))

    @property
    def model_dict(self): 
        return {'vectorizer':self.cv, 'model': self.model}

    @classmethod
    def from_dict(cls, model_dict):
        "Get Model from dictionary"
        nbow_model = cls(len(
            model_dict['vectorizer'].vocabulary_
        ))
        nbow_model.model = model_dict['model']
        nbow_model.cv = model_dict['vectorizer']
        return nbow_model
# Out:
# Overwriting model.py

# %%
# %%writefile baseline_challenge.py
# TODO: In this cell, write your BaselineChallenge flow in the baseline_challenge.py file.

from metaflow import FlowSpec, step, Flow, current, Parameter, IncludeFile, card, current
from metaflow.cards import Table, Markdown, Artifact, Image
import numpy as np 
from dataclasses import dataclass

labeling_function = lambda row: 1 if row['rating']>=4 else 0

@dataclass
class ModelResult:
    "A custom struct for storing model evaluation results."
    name: None
    params: None
    pathspec: None
    acc: None
    rocauc: None

class BaselineChallenge(FlowSpec):

    split_size = Parameter('split-sz', default=0.2)
    data = IncludeFile('data', default='../data/Womens Clothing E-Commerce Reviews.csv')
    kfold = Parameter('k', default=5)
    scoring = Parameter('scoring', default='accuracy')

    @step
    def start(self):

        import pandas as pd
        import io 
        from sklearn.model_selection import train_test_split
        
        # load dataset packaged with the flow.
        # this technique is convenient when working with small datasets that need to move to remove tasks.
        df = pd.read_csv(io.StringIO(self.data), index_col = 0)
        # TODO: load the data. 
        # Look up a few lines to the IncludeFile('data', default='Womens Clothing E-Commerce Reviews.csv'). 
        # You can find documentation on IncludeFile here: https://docs.metaflow.org/scaling/data#data-in-local-files

        # filter down to reviews and labels 
        df.columns = ["_".join(name.lower().strip().split()) for name in df.columns]
        df = df[~df.review_text.isna()]
        df['review'] = df['review_text'].astype('str')
        _has_review_df = df[df['review_text'] != 'nan']
        reviews = _has_review_df['review_text']
        labels = _has_review_df.apply(labeling_function, axis=1)
        self.df = pd.DataFrame({'label': labels, **_has_review_df})

        # split the data 80/20, or by using the flow's split-sz CLI argument
        _df = pd.DataFrame({'review': reviews, 'label': labels})
        self.traindf, self.valdf = train_test_split(_df, test_size=self.split_size)
        print(f'num of rows in train set: {self.traindf.shape[0]}')
        print(f'num of rows in validation set: {self.valdf.shape[0]}')

        self.next(self.baseline, self.model)

    @step
    def baseline(self):
        "Compute the baseline"

        from sklearn.metrics import accuracy_score, roc_auc_score
        self._name = "baseline"
        params = "Always predict 1"
        pathspec = f"{current.flow_name}/{current.run_id}/{current.step_name}/{current.task_id}"

        import numpy as np
        from sklearn.dummy import DummyClassifier
        from sklearn.metrics import accuracy_score, roc_auc_score, confusion_matrix
        np.random.seed(42)
        
        dummy_clf = DummyClassifier(strategy="most_frequent")
        dummy_clf.fit(self.traindf['review'], self.traindf['label'])
        
        predictions = dummy_clf.predict(self.valdf['review'])

        acc = accuracy_score(self.valdf['label'], predictions)
        rocauc = roc_auc_score(self.valdf['label'], predictions)
 
        self.result = ModelResult("Baseline", params, pathspec, acc, rocauc)
        self.next(self.aggregate)

    @step
    def model(self):

        # TODO: import your model if it is defined in another file.
        from model import NbowModel

        self._name = "model"
        # NOTE: If you followed the link above to find a custom model implementation, 
            # you will have noticed your model's vocab_sz hyperparameter.
            # Too big of vocab_sz causes an error. Can you explain why? 
        self.hyperparam_set = [{'vocab_sz': 100}, {'vocab_sz': 300}, {'vocab_sz': 500}]  
        pathspec = f"{current.flow_name}/{current.run_id}/{current.step_name}/{current.task_id}"

        self.results = []
        for params in self.hyperparam_set:
            model = NbowModel(**params) 
            model.fit(X=self.traindf['review'].values, y=self.traindf['label'])
            acc = model.eval_acc(X=self.valdf['review'].values, labels=self.valdf['label']) 
            rocauc = model.eval_rocauc(X=self.valdf['review'].values, labels=self.valdf['label'])
            self.results.append(ModelResult(f"NbowModel - vocab_sz: {params['vocab_sz']}", params, pathspec, acc, rocauc))
        self.next(self.aggregate)

    @step
    def aggregate(self, inputs):
        pass
        self.next(self.end)

    @step
    def end(self):
        pass

if __name__ == '__main__':
    BaselineChallenge()
# Out:
# Overwriting baseline_challenge.py

# %%
! python baseline_challenge.py run --data /home/workspace/workspaces/full-stack-ml-metaflow-corise-week-2/data/Womens\ Clothing\ E-Commerce\ Reviews.csv
# Out:
# Metaflow 2.8.3.1+ob(v1) executing BaselineChallenge for user:sandbox
# Validating your flow...
#     The graph looks good!
# Running pylint...
#     Pylint is happy!
# Including file /home/workspace/workspaces/full-stack-ml-metaflow-corise-week-2/data/Womens Clothing E-Commerce Reviews.csv of size 8MB
# 2023-05-09 06:12:43.225 Workflow starting (run-id 72), see it in the UI at https://ui-pw-673206860.outerbounds.dev/BaselineChallenge/72
# 2023-05-09 06:12:43.412 [72/start/359 (pid 14787)] Task is starting.
# 2023-05-09 06:12:46.691 [72/start/359 (pid 14787)] num of rows in train set: 18112
# 2023-05-09 06:12:49.292 [72/start/359 (pid 14787)] num of rows in validation set: 4529
# 2023-05-09 06:12:49.605 [72/start/359 (pid 14787)] Task finished successfully.
# 2023-05-09 06:12:49.897 [72/baseline/360 (pid 14890)] Task is starting.
# 2023-05-09 06:12:50.050 [72/model/361 (pid 14893)] Task is starting.
# 2023-05-09 06:12:54.372 [72/model/361 (pid 14893)] 2023-05-09 06:12:54.371891: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 AVX512F FMA
# 2023-05-09 06:12:54.504 [72/model/361 (pid 14893)] (18112,)
# 2023-05-09 06:12:55.362 [72/baseline/360 (pid 14890)] Task finished successfully.
# 2023-05-09 06:12:55.502 [72/model/361 (pid 14893)] To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-05-09 06:12:55.502 [72/model/361 (pid 14893)] This is a lovely blouse. i think is a bit roomy, but even so, i like the look. i have to dress business casual for work and this blouse fits the bill as it's not too casual.
# 2023-05-09 06:12:55.502 [72/model/361 (pid 14893)] 2023-05-09 06:12:55.276500: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:116] None of the MLIR optimization passes are enabled (registered 2)
# 2023-05-09 06:12:55.502 [72/model/361 (pid 14893)] Epoch 1/10
# 453/453 [==============================] - 1s 2ms/step - loss: 0.5087 - accuracy: 0.7599 - val_loss: 0.4183 - val_accuracy: 0.8115.7279 - accuracy: 0.40
# 2023-05-09 06:12:56.409 [72/model/361 (pid 14893)] Epoch 2/10
# 453/453 [==============================] - 0s 815us/step - loss: 0.4144 - accuracy: 0.8132 - val_loss: 0.4144 - val_accuracy: 0.81207 - accuracy: 0.84
# 2023-05-09 06:12:56.779 [72/model/361 (pid 14893)] Epoch 3/10
# 453/453 [==============================] - 0s 809us/step - loss: 0.4159 - accuracy: 0.8110 - val_loss: 0.4131 - val_accuracy: 0.81296 - accuracy: 0.87
# 2023-05-09 06:12:57.146 [72/model/361 (pid 14893)] Epoch 4/10
# 453/453 [==============================] - 0s 826us/step - loss: 0.4130 - accuracy: 0.8142 - val_loss: 0.4104 - val_accuracy: 0.81764 - accuracy: 0.87
# 2023-05-09 06:12:57.521 [72/model/361 (pid 14893)] Epoch 5/10
# 453/453 [==============================] - 0s 816us/step - loss: 0.3967 - accuracy: 0.8256 - val_loss: 0.4120 - val_accuracy: 0.81876 - accuracy: 0.71
# 2023-05-09 06:12:57.892 [72/model/361 (pid 14893)] Epoch 6/10
# 453/453 [==============================] - 0s 808us/step - loss: 0.4092 - accuracy: 0.8215 - val_loss: 0.4105 - val_accuracy: 0.81920 - accuracy: 0.81
# 2023-05-09 06:12:58.258 [72/model/361 (pid 14893)] Epoch 7/10
# 453/453 [==============================] - 0s 812us/step - loss: 0.3995 - accuracy: 0.8265 - val_loss: 0.4099 - val_accuracy: 0.82037 - accuracy: 0.87
# 2023-05-09 06:12:58.627 [72/model/361 (pid 14893)] Epoch 8/10
# 453/453 [==============================] - 0s 827us/step - loss: 0.3968 - accuracy: 0.8252 - val_loss: 0.4094 - val_accuracy: 0.81870 - accuracy: 0.84
# 2023-05-09 06:12:59.002 [72/model/361 (pid 14893)] Epoch 9/10
# 453/453 [==============================] - 0s 785us/step - loss: 0.3951 - accuracy: 0.8237 - val_loss: 0.4087 - val_accuracy: 0.82119 - accuracy: 0.81
# 2023-05-09 06:12:59.359 [72/model/361 (pid 14893)] Epoch 10/10
# 453/453 [==============================] - 0s 784us/step - loss: 0.3870 - accuracy: 0.8328 - val_loss: 0.4105 - val_accuracy: 0.81455 - accuracy: 0.90
# 2023-05-09 06:12:59.786 [72/model/361 (pid 14893)] (4529,)
# 2023-05-09 06:13:00.058 [72/model/361 (pid 14893)] When i saw this dress online - it was a must have. i preordered immediately and had my fingers crossed that i'd get it! thankfully it did! this dress has blown me away. it exceeds all expectations!!! i ordered an xl which is a normal size for me and i'm glad i did! the body is very swingy but the top is true to size. the print is magical. whimsical, bold,  bohemian and transitional into every single season. i am 5'8 and the dress hits just above my knees. i feel gorgeous in it. the "woven cotton
# 2023-05-09 06:13:00.058 [72/model/361 (pid 14893)] (4529,)
# 2023-05-09 06:13:00.307 [72/model/361 (pid 14893)] When i saw this dress online - it was a must have. i preordered immediately and had my fingers crossed that i'd get it! thankfully it did! this dress has blown me away. it exceeds all expectations!!! i ordered an xl which is a normal size for me and i'm glad i did! the body is very swingy but the top is true to size. the print is magical. whimsical, bold,  bohemian and transitional into every single season. i am 5'8 and the dress hits just above my knees. i feel gorgeous in it. the "woven cotton
# 2023-05-09 06:13:00.307 [72/model/361 (pid 14893)] (18112,)
# 2023-05-09 06:13:01.102 [72/model/361 (pid 14893)] This is a lovely blouse. i think is a bit roomy, but even so, i like the look. i have to dress business casual for work and this blouse fits the bill as it's not too casual.
# 2023-05-09 06:13:01.102 [72/model/361 (pid 14893)] Epoch 1/10
# 453/453 [==============================] - 1s 1ms/step - loss: 0.4733 - accuracy: 0.7899 - val_loss: 0.3542 - val_accuracy: 0.8526.6857 - accuracy: 0.59
# 2023-05-09 06:13:01.873 [72/model/361 (pid 14893)] Epoch 2/10
# 453/453 [==============================] - 0s 881us/step - loss: 0.3578 - accuracy: 0.8413 - val_loss: 0.3503 - val_accuracy: 0.85153 - accuracy: 0.78
# 2023-05-09 06:13:02.273 [72/model/361 (pid 14893)] Epoch 3/10
# 453/453 [==============================] - 0s 880us/step - loss: 0.3456 - accuracy: 0.8537 - val_loss: 0.3507 - val_accuracy: 0.85218 - accuracy: 0.78
# 2023-05-09 06:13:02.673 [72/model/361 (pid 14893)] Epoch 4/10
# 453/453 [==============================] - 0s 904us/step - loss: 0.3353 - accuracy: 0.8613 - val_loss: 0.3494 - val_accuracy: 0.85378 - accuracy: 0.78
# 2023-05-09 06:13:03.083 [72/model/361 (pid 14893)] Epoch 5/10
# 453/453 [==============================] - 0s 892us/step - loss: 0.3238 - accuracy: 0.8662 - val_loss: 0.3514 - val_accuracy: 0.85210 - accuracy: 0.96
# 2023-05-09 06:13:03.488 [72/model/361 (pid 14893)] Epoch 6/10
# 453/453 [==============================] - 0s 883us/step - loss: 0.3253 - accuracy: 0.8644 - val_loss: 0.3518 - val_accuracy: 0.85260 - accuracy: 0.90
# 2023-05-09 06:13:03.888 [72/model/361 (pid 14893)] Epoch 7/10
# 453/453 [==============================] - 0s 888us/step - loss: 0.3168 - accuracy: 0.8690 - val_loss: 0.3530 - val_accuracy: 0.85568 - accuracy: 0.90
# 2023-05-09 06:13:04.291 [72/model/361 (pid 14893)] Epoch 8/10
# 453/453 [==============================] - 0s 907us/step - loss: 0.3056 - accuracy: 0.8801 - val_loss: 0.3579 - val_accuracy: 0.85453 - accuracy: 0.84
# 2023-05-09 06:13:04.704 [72/model/361 (pid 14893)] Epoch 9/10
# 453/453 [==============================] - 0s 903us/step - loss: 0.3018 - accuracy: 0.8793 - val_loss: 0.3593 - val_accuracy: 0.85347 - accuracy: 0.87
# 2023-05-09 06:13:05.114 [72/model/361 (pid 14893)] Epoch 10/10
# 453/453 [==============================] - 0s 894us/step - loss: 0.2998 - accuracy: 0.8788 - val_loss: 0.3608 - val_accuracy: 0.85187 - accuracy: 0.81
# 2023-05-09 06:13:05.523 [72/model/361 (pid 14893)] (4529,)
# 2023-05-09 06:13:05.790 [72/model/361 (pid 14893)] When i saw this dress online - it was a must have. i preordered immediately and had my fingers crossed that i'd get it! thankfully it did! this dress has blown me away. it exceeds all expectations!!! i ordered an xl which is a normal size for me and i'm glad i did! the body is very swingy but the top is true to size. the print is magical. whimsical, bold,  bohemian and transitional into every single season. i am 5'8 and the dress hits just above my knees. i feel gorgeous in it. the "woven cotton
# 2023-05-09 06:13:05.790 [72/model/361 (pid 14893)] (4529,)
# 2023-05-09 06:13:06.053 [72/model/361 (pid 14893)] When i saw this dress online - it was a must have. i preordered immediately and had my fingers crossed that i'd get it! thankfully it did! this dress has blown me away. it exceeds all expectations!!! i ordered an xl which is a normal size for me and i'm glad i did! the body is very swingy but the top is true to size. the print is magical. whimsical, bold,  bohemian and transitional into every single season. i am 5'8 and the dress hits just above my knees. i feel gorgeous in it. the "woven cotton
# 2023-05-09 06:13:06.053 [72/model/361 (pid 14893)] (18112,)
# 2023-05-09 06:13:06.874 [72/model/361 (pid 14893)] This is a lovely blouse. i think is a bit roomy, but even so, i like the look. i have to dress business casual for work and this blouse fits the bill as it's not too casual.
# 2023-05-09 06:13:06.874 [72/model/361 (pid 14893)] Epoch 1/10
# 453/453 [==============================] - 1s 1ms/step - loss: 0.4475 - accuracy: 0.7987 - val_loss: 0.3425 - val_accuracy: 0.8545.6256 - accuracy: 0.78
# 2023-05-09 06:13:07.687 [72/model/361 (pid 14893)] Epoch 2/10
# 453/453 [==============================] - 0s 999us/step - loss: 0.3189 - accuracy: 0.8682 - val_loss: 0.3391 - val_accuracy: 0.85238 - accuracy: 0.84
# 2023-05-09 06:13:08.140 [72/model/361 (pid 14893)] Epoch 3/10
# 453/453 [==============================] - 0s 1ms/step - loss: 0.3159 - accuracy: 0.8686 - val_loss: 0.3362 - val_accuracy: 0.8612662 - accuracy: 0.93
# 2023-05-09 06:13:08.609 [72/model/361 (pid 14893)] Epoch 4/10
# 453/453 [==============================] - 0s 1ms/step - loss: 0.3051 - accuracy: 0.8719 - val_loss: 0.3362 - val_accuracy: 0.8598475 - accuracy: 0.87
# 2023-05-09 06:13:09.091 [72/model/361 (pid 14893)] Epoch 5/10
# 453/453 [==============================] - 0s 1ms/step - loss: 0.2970 - accuracy: 0.8755 - val_loss: 0.3408 - val_accuracy: 0.8592829 - accuracy: 0.81
# 2023-05-09 06:13:09.550 [72/model/361 (pid 14893)] Epoch 6/10
# 453/453 [==============================] - 0s 1ms/step - loss: 0.2967 - accuracy: 0.8781 - val_loss: 0.3407 - val_accuracy: 0.8579331 - accuracy: 0.87
# 2023-05-09 06:13:10.009 [72/model/361 (pid 14893)] Epoch 7/10
# 453/453 [==============================] - 0s 1ms/step - loss: 0.2845 - accuracy: 0.8832 - val_loss: 0.3409 - val_accuracy: 0.8587723 - accuracy: 0.90
# 2023-05-09 06:13:10.470 [72/model/361 (pid 14893)] Epoch 8/10
# 453/453 [==============================] - 0s 1ms/step - loss: 0.2765 - accuracy: 0.8891 - val_loss: 0.3456 - val_accuracy: 0.8598066 - accuracy: 0.87
# 2023-05-09 06:13:10.927 [72/model/361 (pid 14893)] Epoch 9/10
# 453/453 [==============================] - 0s 1ms/step - loss: 0.2871 - accuracy: 0.8887 - val_loss: 0.3470 - val_accuracy: 0.8614392 - accuracy: 0.87
# 2023-05-09 06:13:11.392 [72/model/361 (pid 14893)] Epoch 10/10
# 453/453 [==============================] - 0s 1ms/step - loss: 0.2606 - accuracy: 0.8990 - val_loss: 0.3534 - val_accuracy: 0.8603388 - accuracy: 0.81
# 2023-05-09 06:13:11.859 [72/model/361 (pid 14893)] (4529,)
# 2023-05-09 06:13:12.121 [72/model/361 (pid 14893)] When i saw this dress online - it was a must have. i preordered immediately and had my fingers crossed that i'd get it! thankfully it did! this dress has blown me away. it exceeds all expectations!!! i ordered an xl which is a normal size for me and i'm glad i did! the body is very swingy but the top is true to size. the print is magical. whimsical, bold,  bohemian and transitional into every single season. i am 5'8 and the dress hits just above my knees. i feel gorgeous in it. the "woven cotton
# 2023-05-09 06:13:12.121 [72/model/361 (pid 14893)] (4529,)
# 2023-05-09 06:13:14.922 [72/model/361 (pid 14893)] 2023-05-09 06:12:55.276867: I tensorflow/core/platform/profile_utils/cpu_utils.cc:112] CPU Frequency: 2500000000 Hz
# 2023-05-09 06:13:14.922 [72/model/361 (pid 14893)] When i saw this dress online - it was a must have. i preordered immediately and had my fingers crossed that i'd get it! thankfully it did! this dress has blown me away. it exceeds all expectations!!! i ordered an xl which is a normal size for me and i'm glad i did! the body is very swingy but the top is true to size. the print is magical. whimsical, bold,  bohemian and transitional into every single season. i am 5'8 and the dress hits just above my knees. i feel gorgeous in it. the "woven cotton
# 2023-05-09 06:13:15.168 [72/model/361 (pid 14893)] Task finished successfully.
# 2023-05-09 06:13:15.543 [72/aggregate/362 (pid 15220)] Task is starting.
# 2023-05-09 06:13:18.325 [72/aggregate/362 (pid 15220)] Task finished successfully.
# 2023-05-09 06:13:18.620 [72/end/363 (pid 15277)] Task is starting.
# 2023-05-09 06:13:20.982 [72/end/363 (pid 15277)] Task finished successfully.
# 2023-05-09 06:13:21.109 Done! See the run in the UI at https://ui-pw-673206860.outerbounds.dev/BaselineChallenge/72

# %% [markdown]
# ## Task 2: Anticipating Failure in Your Machine Learning Project
#
# In this task, you'll practice anticipating potential failure modes in a sentiment analysis classifier and develop strategies to mitigate them. Here's what you'll need to do:
# ### Step 1: Identify Potential Failure Modes
#
# The first step in anticipating failure in your machine learning project is to identify potential failure modes. Start by brainstorming ways in which your project could fail from an engineering point of view. For example, your model could overfit to the training data or suffer from data bias.
#
# ##### significant change class skew in daily data
# ##### data bias
# ##### discrimination like gender bias, socio-economic bias, racial bias etc
# ##### label error
# ##### sensitivity to data noise
# ##### sensitivity to label noise
# ##### underfitting / over fitting
# ##### sudden large change in driving metrics
# ##### choice of metrics
# #####
#
#
# ### Step 2: Develop Strategies to Mitigate Failure Modes
#
# Once you've identified potential failure modes, the next step is to develop strategies to mitigate them. Think about what measures you could take to fix the issue if it were to occur. For example, if your model is overfitting to the training data, you could try regularization techniques such as L1 or L2 regularization to reduce the complexity of the model.
#
#
# ##### check class skew in daily data
# ##### check data bias : check population bias because of nature of data presentation/collection (like 1st slot getting very high clicks independent of content). Fix it if possible, using methods like IPW, DR etc on loss like click prediction loss and rate features like CTR.
# ##### check discrimination : check for gender bias, socio-economic bias, racial bias etc
# ##### find label error using label correction libraries
# ##### model sensitivity to data noise: data augmentation
# ##### analysis on model sensitivity to label noise
# ##### check underfitting / over fitting: increase model complexity / add regularisation
# ##### if learning not happening use batch norm and stuff for improve loss surface or gradient magnitude / co-variate shift
# ##### gaurd rails (sudden large change in metrics): have alerts for metrics moving out of gaurd rails
# ##### run offline test to validate improvement (if possible do counterfactual evaluation to measure improvement)
#
#
# ### Step 3: Plan Ahead to Avoid Failure Modes
#
# Finally, it's important to plan ahead to avoid potential failure modes in the first place. Think about what you could have done initially to avoid these failure modes. For example, you could have collected a diverse set of training data to reduce data bias or experimented with different model architectures to find the best solution for your problem.
#
# The key to anticipating failure in your machine learning project is to be proactive rather than reactive. By identifying potential failure modes ahead of time and developing strategies to mitigate them, you'll be better equipped to build a successful machine learning project.

# %% [markdown]
# ## Task 3: Visualizing ML Results with MF Cards
# Now it is time to iterate. Extend the flow in your `baseline_challenge.py` file to include a step that aggregates all of the results from hyperparameter tuning jobs, and logs results and a data visualiation in a Metaflow card.

# %%
# %%writefile baseline_challenge_1.py
# TODO: In this cell, write your BaselineChallenge flow in the baseline_challenge.py file.

from metaflow import FlowSpec, step, Flow, current, Parameter, IncludeFile, card, current
from metaflow.cards import Table, Markdown, Artifact, Image
import numpy as np 
from dataclasses import dataclass


labeling_function = lambda row: 1 if row['rating']>=4 else 0

@dataclass
class ModelResult:
    "A custom struct for storing model evaluation results."
    name: None
    params: None
    pathspec: None
    acc: None
    rocauc: None

class BaselineChallenge(FlowSpec):

    split_size = Parameter('split-sz', default=0.2)
    data = IncludeFile('data', default='Womens Clothing E-Commerce Reviews.csv')
    kfold = Parameter('k', default=5)
    scoring = Parameter('scoring', default='accuracy')
    @step
    def start(self):

        import pandas as pd
        import io 
        from sklearn.model_selection import train_test_split
        
        # load dataset packaged with the flow.
        # this technique is convenient when working with small datasets that need to move to remove tasks.
        df = pd.read_csv(io.StringIO(self.data), index_col = 0)
        # TODO: load the data. 
        # Look up a few lines to the IncludeFile('data', default='Womens Clothing E-Commerce Reviews.csv'). 
        # You can find documentation on IncludeFile here: https://docs.metaflow.org/scaling/data#data-in-local-files

        # filter down to reviews and labels 
        df.columns = ["_".join(name.lower().strip().split()) for name in df.columns]
        df = df[~df.review_text.isna()]
        df['review'] = df['review_text'].astype('str')
        _has_review_df = df[df['review_text'] != 'nan']
        reviews = _has_review_df['review_text']
        labels = _has_review_df.apply(labeling_function, axis=1)
        self.df = pd.DataFrame({'label': labels, **_has_review_df})

        # split the data 80/20, or by using the flow's split-sz CLI argument
        _df = pd.DataFrame({'review': reviews, 'label': labels})
        self.traindf, self.valdf = train_test_split(_df, test_size=self.split_size)
        print(f'num of rows in train set: {self.traindf.shape[0]}')
        print(f'num of rows in validation set: {self.valdf.shape[0]}')

        self.next(self.baseline, self.model)

    @step
    def baseline(self):
        "Compute the baseline"

        self._name = "baseline"
        params = "Always predict 1"
        pathspec = f"{current.flow_name}/{current.run_id}/{current.step_name}/{current.task_id}"

        import numpy as np
        from sklearn.dummy import DummyClassifier
        from sklearn.metrics import accuracy_score, roc_auc_score, confusion_matrix
        np.random.seed(42)
        
        dummy_clf = DummyClassifier(strategy="most_frequent")
        dummy_clf.fit(self.traindf['review'], self.traindf['label'])
        
        predictions = dummy_clf.predict(self.valdf['review'])

        acc = accuracy_score(self.valdf['label'], predictions)
        rocauc = roc_auc_score(self.valdf['label'], predictions)
 
        self.result = ModelResult("Baseline", params, pathspec, acc, rocauc)
        self.next(self.aggregate)

    @step
    def model(self):

        # TODO: import your model if it is defined in another file.
        from model import NbowModel

        self._name = "model"
        # NOTE: If you followed the link above to find a custom model implementation, 
            # you will have noticed your model's vocab_sz hyperparameter.
            # Too big of vocab_sz causes an error. Can you explain why? 
        self.hyperparam_set = [{'vocab_sz': 100}, {'vocab_sz': 300}, {'vocab_sz': 500}]  
        pathspec = f"{current.flow_name}/{current.run_id}/{current.step_name}/{current.task_id}"

        self.results = []
        for params in self.hyperparam_set:
            model = NbowModel(**params) 
            model.fit(X=self.traindf['review'].values, y=self.traindf['label'])
            acc = model.eval_acc(X=self.valdf['review'].values, labels=self.valdf['label']) 
            rocauc = model.eval_rocauc(X=self.valdf['review'].values, labels=self.valdf['label'])
            self.results.append(ModelResult(f"NbowModel - vocab_sz: {params['vocab_sz']}", params, pathspec, acc, rocauc))
        self.next(self.aggregate)

    def add_one(self, rows, result, df):
        "A helper function to load results."
        rows.append([
            Markdown(result.name),
            Artifact(result.params),
            Artifact(result.pathspec),
            Artifact(result.acc),
            Artifact(result.rocauc)
        ])
        df['name'].append(result.name)
        df['accuracy'].append(result.acc)
        return rows, df

    @card(type="corise") # TODO: Set your card type to "corise". 
            # I wonder what other card types there are?
            # https://docs.metaflow.org/metaflow/visualizing-results
            # https://github.com/outerbounds/metaflow-card-altair/blob/main/altairflow.py
    @step
    def aggregate(self, inputs):

        import seaborn as sns
        import matplotlib.pyplot as plt
        from matplotlib import rcParams 
        rcParams.update({'figure.autolayout': True})

        rows = []
        violin_plot_df = {'name': [], 'accuracy': []}
        for task in inputs:
            if task._name == "model": 
                for result in task.results:
                    print(result)
                    rows, violin_plot_df = self.add_one(rows, result, violin_plot_df)
            elif task._name == "baseline":
                print(task.result)
                rows, violin_plot_df = self.add_one(rows, task.result, violin_plot_df)
            else:
                raise ValueError("Unknown task._name type. Cannot parse results.")
            
        current.card.append(Markdown("# All models from this flow run"))

        # TODO: Add a Table of the results to your card! 
        current.card.append(
            Table(
                rows, # TODO: What goes here to populate the Table in the card? 
                headers=["Model name", "Params", "Task pathspec", "Accuracy", "ROCAUC"]
            )
        )
        
        fig, ax = plt.subplots(1,1)
        plt.xticks(rotation=40)
        sns.violinplot(data=violin_plot_df, x="name", y="accuracy", ax=ax)
        
        # TODO: Append the matplotlib fig to the card
        # Docs: https://docs.metaflow.org/metaflow/visualizing-results/easy-custom-reports-with-card-components#showing-plots
        current.card.append(Image.from_matplotlib(fig))
        
        self.next(self.end)

    @step
    def end(self):
        pass

if __name__ == '__main__':
    BaselineChallenge()
# Out:
# Overwriting baseline_challenge_1.py

# %%
! python baseline_challenge_1.py run --data /home/workspace/workspaces/full-stack-ml-metaflow-corise-week-2/data/Womens\ Clothing\ E-Commerce\ Reviews.csv
# Out:
# Metaflow 2.8.3.1+ob(v1) executing BaselineChallenge for user:sandbox
# Validating your flow...
#     The graph looks good!
# Running pylint...
#     Pylint is happy!
# Including file /home/workspace/workspaces/full-stack-ml-metaflow-corise-week-2/data/Womens Clothing E-Commerce Reviews.csv of size 8MB
# 2023-05-09 06:13:34.454 Workflow starting (run-id 73), see it in the UI at https://ui-pw-673206860.outerbounds.dev/BaselineChallenge/73
# 2023-05-09 06:13:34.737 [73/start/365 (pid 15365)] Task is starting.
# 2023-05-09 06:13:37.862 [73/start/365 (pid 15365)] num of rows in train set: 18112
# 2023-05-09 06:13:40.511 [73/start/365 (pid 15365)] num of rows in validation set: 4529
# 2023-05-09 06:13:40.708 [73/start/365 (pid 15365)] Task finished successfully.
# 2023-05-09 06:13:40.980 [73/baseline/366 (pid 15465)] Task is starting.
# 2023-05-09 06:13:41.162 [73/model/367 (pid 15468)] Task is starting.
# 2023-05-09 06:13:45.336 [73/model/367 (pid 15468)] 2023-05-09 06:13:45.336591: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 AVX512F FMA
# 2023-05-09 06:13:45.460 [73/model/367 (pid 15468)] (18112,)
# 2023-05-09 06:13:46.347 [73/baseline/366 (pid 15465)] Task finished successfully.
# 2023-05-09 06:13:46.520 [73/model/367 (pid 15468)] To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-05-09 06:13:46.520 [73/model/367 (pid 15468)] I love this top because it can be worn on or off the shoulders and looks equally as cute either way, i bought the red color and it is super cheerful and perfect for summer. looks great with faded jeans. i love the poplin fabric, although the stitching quality is shabby and i expect this won't hold up long enough to wear again next summer. for the price i feel like it should be crafted a little bit better. i am narrow shoulder'd and bra size 36 b or c and while a medium might have fit me better o
# 2023-05-09 06:13:46.520 [73/model/367 (pid 15468)] 2023-05-09 06:13:46.152266: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:116] None of the MLIR optimization passes are enabled (registered 2)
# 2023-05-09 06:13:46.521 [73/model/367 (pid 15468)] Epoch 1/10
# 453/453 [==============================] - 1s 2ms/step - loss: 0.5036 - accuracy: 0.7731 - val_loss: 0.4209 - val_accuracy: 0.8035.7018 - accuracy: 0.59
# 2023-05-09 06:13:47.297 [73/model/367 (pid 15468)] Epoch 2/10
# 453/453 [==============================] - 0s 820us/step - loss: 0.4144 - accuracy: 0.8175 - val_loss: 0.4160 - val_accuracy: 0.81151 - accuracy: 0.84
# 2023-05-09 06:13:47.669 [73/model/367 (pid 15468)] Epoch 3/10
# 453/453 [==============================] - 0s 791us/step - loss: 0.4125 - accuracy: 0.8153 - val_loss: 0.4126 - val_accuracy: 0.81566 - accuracy: 0.87
# 2023-05-09 06:13:48.028 [73/model/367 (pid 15468)] Epoch 4/10
epoch 4/10
# 453/453 [==============================] - 0s 1ms/step - loss: 0.3128 - accuracy: 0.8694 - val_loss: 0.3447 - val_accuracy: 0.8579655 - accuracy: 0.87
# 2023-05-09 06:13:59.760 [73/model/367 (pid 15468)] Epoch 5/10
# 453/453 [==============================] - 0s 1ms/step - loss: 0.2970 - accuracy: 0.8803 - val_loss: 0.3489 - val_accuracy: 0.8576249 - accuracy: 0.93
# 2023-05-09 06:14:00.215 [73/model/367 (pid 15468)] Epoch 6/10
# 453/453 [==============================] - 0s 1ms/step - loss: 0.2885 - accuracy: 0.8837 - val_loss: 0.3539 - val_accuracy: 0.8543998 - accuracy: 0.93
# 2023-05-09 06:14:00.669 [73/model/367 (pid 15468)] Epoch 7/10
# 453/453 [==============================] - 0s 1ms/step - loss: 0.2728 - accuracy: 0.8910 - val_loss: 0.3580 - val_accuracy: 0.8554393 - accuracy: 0.87
# 2023-05-09 06:14:01.126 [73/model/367 (pid 15468)] Epoch 8/10
# 453/453 [==============================] - 0s 1ms/step - loss: 0.2686 - accuracy: 0.8968 - val_loss: 0.3621 - val_accuracy: 0.8490134 - accuracy: 0.81
# 2023-05-09 06:14:01.588 [73/model/367 (pid 15468)] Epoch 9/10
# 453/453 [==============================] - 0s 1ms/step - loss: 0.2677 - accuracy: 0.8973 - val_loss: 0.3678 - val_accuracy: 0.8518172 - accuracy: 0.84
# 2023-05-09 06:14:02.052 [73/model/367 (pid 15468)] Epoch 10/10
# 453/453 [==============================] - 0s 1ms/step - loss: 0.2635 - accuracy: 0.8969 - val_loss: 0.3759 - val_accuracy: 0.8479444 - accuracy: 0.81
# 2023-05-09 06:14:02.511 [73/model/367 (pid 15468)] (4529,)
# 2023-05-09 06:14:02.767 [73/model/367 (pid 15468)] Has anybody washed this shirt a second time? just curious if it continues to shrink.
# 2023-05-09 06:14:02.767 [73/model/367 (pid 15468)] (4529,)
# 2023-05-09 06:14:05.724 [73/model/367 (pid 15468)] 2023-05-09 06:13:46.169870: I tensorflow/core/platform/profile_utils/cpu_utils.cc:112] CPU Frequency: 2500000000 Hz
# 2023-05-09 06:14:05.724 [73/model/367 (pid 15468)] Has anybody washed this shirt a second time? just curious if it continues to shrink.
# 2023-05-09 06:14:06.004 [73/model/367 (pid 15468)] Task finished successfully.
# 2023-05-09 06:14:06.391 [73/aggregate/368 (pid 15785)] Task is starting.
# 2023-05-09 06:14:09.516 [73/aggregate/368 (pid 15785)] ModelResult(name='Baseline', params='Always predict 1', pathspec='BaselineChallenge/73/baseline/366', acc=0.7633031574298962, rocauc=0.5)
# 2023-05-09 06:14:09.567 [73/aggregate/368 (pid 15785)] ModelResult(name='NbowModel - vocab_sz: 100', params={'vocab_sz': 100}, pathspec='BaselineChallenge/73/model/367', acc=0.8120998012806359, rocauc=0.8318214665031798)
# 2023-05-09 06:14:09.567 [73/aggregate/368 (pid 15785)] ModelResult(name='NbowModel - vocab_sz: 300', params={'vocab_sz': 300}, pathspec='BaselineChallenge/73/model/367', acc=0.8511812762199161, rocauc=0.8881836928317626)
# 2023-05-09 06:14:12.256 [73/aggregate/368 (pid 15785)] ModelResult(name='NbowModel - vocab_sz: 500', params={'vocab_sz': 500}, pathspec='BaselineChallenge/73/model/367', acc=0.8560388606756458, rocauc=0.9005748664833194)
# 2023-05-09 06:14:12.464 [73/aggregate/368 (pid 15785)] Task finished successfully.
# 2023-05-09 06:14:12.839 [73/end/369 (pid 15881)] Task is starting.
# 2023-05-09 06:14:15.223 [73/end/369 (pid 15881)] Task finished successfully.
# 2023-05-09 06:14:15.385 Done! See the run in the UI at https://ui-pw-673206860.outerbounds.dev/BaselineChallenge/73

# %%
from metaflow import Flow, Metaflow, Run, Step, Task

# list all flow runs
for flow in Metaflow():
    print(flow)
# Out:
# Flow('Template_Flow')
# Flow('TFlow1')
# Flow('RF_Flow')
# Flow('BSTFlow')
# Flow('NNFlow')
# Flow('BaselineNLPFlow')
# Flow('GoodFirstModelNLPFlow')
# Flow('Branch_Flow')
# Flow('TFlow2')
# Flow('TFlow3')
# Flow('TFlow4')
# Flow('TFlow5')
# Flow('BaselineChallenge')

# %%
# list all runs of a flow
for run in Flow('BaselineChallenge'):
    print(run)
# Out:
# Run('BaselineChallenge/73')
# Run('BaselineChallenge/72')
# Run('BaselineChallenge/71')
# Run('BaselineChallenge/70')
# Run('BaselineChallenge/69')
# Run('BaselineChallenge/68')
# Run('BaselineChallenge/67')
# Run('BaselineChallenge/66')
# Run('BaselineChallenge/65')
# Run('BaselineChallenge/64')
# Run('BaselineChallenge/63')
# Run('BaselineChallenge/62')
# Run('BaselineChallenge/61')
# Run('BaselineChallenge/60')
# Run('BaselineChallenge/59')
# Run('BaselineChallenge/58')
# Run('BaselineChallenge/57')
# Run('BaselineChallenge/56')
# Run('BaselineChallenge/55')
# Run('BaselineChallenge/54')
# Run('BaselineChallenge/53')
# Run('BaselineChallenge/52')
# Run('BaselineChallenge/51')
# Run('BaselineChallenge/50')
# Run('BaselineChallenge/49')
# Run('BaselineChallenge/48')
# Run('BaselineChallenge/47')
# Run('BaselineChallenge/46')
# Run('BaselineChallenge/45')

# %%
#latest run of a flow and check if its successful
latest_run = Flow('BaselineChallenge').latest_run
print(latest_run)
print(latest_run.successful)
# Out:
# Run('BaselineChallenge/73')
# True

# %%
#all steps in latest run
for step in Flow('BaselineChallenge').latest_run:
    print(step)
# Out:
# Step('BaselineChallenge/73/end')
# Step('BaselineChallenge/73/aggregate')
# Step('BaselineChallenge/73/model')
# Step('BaselineChallenge/73/baseline')
# Step('BaselineChallenge/73/start')

# %%
# list all task in a Step
for task in Step('BaselineChallenge/71/model'):
    print(task)
# Out:
# Task('BaselineChallenge/71/model/355')

# %%
# list all task in all step which failed
# TODO what is task specifically??
for step in Run('BaselineChallenge/45'):
    for task in step:
        if not task.successful:
            print("Task {} failed".format(task.pathspec))
# Out:
# Task BaselineChallenge/45/model/238 failed

# %%
# list all data artifacts in a Task
for dataArtifact in Task('BaselineChallenge/71/model/355'):
    print(dataArtifact)
# Out:
# DataArtifact('BaselineChallenge/71/model/355/hyperparam_set')
# DataArtifact('BaselineChallenge/71/model/355/results')
# DataArtifact('BaselineChallenge/71/model/355/df')
# DataArtifact('BaselineChallenge/71/model/355/traindf')
# DataArtifact('BaselineChallenge/71/model/355/valdf')
# DataArtifact('BaselineChallenge/71/model/355/data')
# DataArtifact('BaselineChallenge/71/model/355/kfold')
# DataArtifact('BaselineChallenge/71/model/355/name')
# DataArtifact('BaselineChallenge/71/model/355/scoring')
# DataArtifact('BaselineChallenge/71/model/355/split_size')

# %%
from metaflow import DataArtifact
print(dir(Task('BaselineChallenge/71/model/355')['hyperparam_set']))
print(Task('BaselineChallenge/71/model/355')['hyperparam_set'].data)
# Out:
# ['_CHILD_CLASS', '_NAME', '_PARENT_CLASS', '__class__', '__contains__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_attempt', '_created_at', '_filtered_children', '_get_child', '_get_object', '_ipython_key_completions_', '_iter_filter', '_metaflow', '_namespace_check', '_object', '_parent', '_path_components', '_pathspec', '_system_tags', '_tags', '_url_token', '_user_tags', 'created_at', 'data', 'finished_at', 'id', 'is_in_namespace', 'origin_pathspec', 'parent', 'path_components', 'pathspec', 'sha', 'size', 'system_tags', 'tags', 'user_tags']
# [{'vocab_sz': 100}, {'vocab_sz': 300}, {'vocab_sz': 500}]
