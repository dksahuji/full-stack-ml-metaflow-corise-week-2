# %% [markdown]
# # Week 2 Project

# %% [markdown]
# Once again, we’ll be using the [Women's Ecommerce Clothing Reviews Dataset from Kaggle](https://www.kaggle.com/datasets/nicapotato/womens-ecommerce-clothing-reviews), which Kaggle states is a
#
# > dataset revolving around the reviews written by customers. Its nine supportive features offer a great environment to parse out the text through its multiple dimensions. Because this is real commercial data, it has been anonymized, and references to the company in the review text and body have been replaced with “retailer”.
#
# The machine learning task will be sentiment analysis, classifying each review as having positive or negative sentiment.

# %% [markdown]
# ## Task 1: Training and Evaluating Sentiment Analysis Models Using Metaflow
#
# In this task, you'll use Metaflow to build two machine learning models for sentiment analysis: a baseline *"majority class"* classifier and your own custom model. You'll then train both models in parallel and experiment with different hyperparameters to optimize their performance. Finally, you'll use this notebook and the Metaflow Client API to analyze the results of your different models and hyperparameters. Here's what you'll need to do:
#
# ### Step 1: Build the Workflows
# The first step in this task is to build the workflow(s) for sentiment analysis using the Metaflow framework. Start by creating a new flow in Metaflow and implementing the baseline *"majority class"* classifier. Then, build your own custom classifier using techniques you learned in Week 1, or any [helpful resources](https://outerbounds.com/docs/nlp-tutorial-L2/) you'd like. For your custom model, be sure to include steps for data preprocessing, model training, and evaluation.
#
# ### Step 2: Train Both Models in Parallel
# Once you've built your models, the next step is to train both models in parallel using the Metaflow framework. Use Metaflow to run both training jobs in parallel steps. If you get stuck, you may want to review the [FlowSpec branching documentation](https://docs.metaflow.org/metaflow/basics#branch).
#
# ### Step 3: Experiment with Hyperparameters
# After you've trained both models in parallel, the next step is to experiment with different hyperparameters to optimize their performance. Try different values for hyperparameters such as learning rate, batch size, and number of epochs, and record the results for each combination of hyperparameters as Data Artifacts in Metaflow.
#
# ### Step 4: Analyze the Results
# Finally, use this notebook and the Metaflow Client API to analyze the results of your different models and hyperparameters. Create visualizations to compare the performance of the two models and identify the best hyperparameters for each one.
#
# By completing this task, you'll gain experience working with the Metaflow framework and learn how to build and optimize machine learning workflows for sentiment analysis.

# %%
from collections import Counter
import pandas as pd
import numpy as np 
from termcolor import colored
import matplotlib.pyplot as plt
import seaborn as sns
import string

# You can style your plots here, but it is not part of the project.
YELLOW = '#FFBC00'
GREEN = '#37795D'
PURPLE = '#5460C0'
BACKGROUND = '#F4EBE6'
colors = [GREEN, PURPLE]
custom_params = {
    'axes.spines.right': False, 'axes.spines.top': False,
    'axes.facecolor':BACKGROUND, 'figure.facecolor': BACKGROUND, 
    'figure.figsize':(8, 8)
}
sns_palette = sns.color_palette(colors, len(colors))
sns.set_theme(style='ticks', rc=custom_params)

# %%
import io
from sklearn.model_selection import train_test_split

# TODO: load the data. 
df = pd.read_csv("../data/Womens Clothing E-Commerce Reviews.csv")
labeling_function = lambda row: 1 if row['rating']>=4 else 0
# transformations
df.columns = ["_".join(name.lower().strip().split()) for name in df.columns]
df = df[~df.review_text.isna()]
df['review'] = df['review_text'].astype('str')
_has_review_df = df[df['review_text'] != 'nan']
reviews = _has_review_df['review_text']
labels = _has_review_df.apply(labeling_function, axis=1)
df = pd.DataFrame({'label': labels, **_has_review_df})

# split into training and validation.
_df = pd.DataFrame({'review': reviews, 'label': labels})
traindf, valdf = train_test_split(_df, test_size=0.2)

# %%
# TODO: build the majority class baseline model. 
# TODO: find the majority class in the labels. 🤔
# TODO: score the model on valdf with a 2D metric space: sklearn.metrics.accuracy_score, sklearn.metrics.roc_auc_score
    # Documentation on suggested model-scoring approach: https://scikit-learn.org/stable/modules/model_evaluation.html

import numpy as np
from sklearn.dummy import DummyClassifier
from sklearn.metrics import accuracy_score, roc_auc_score, confusion_matrix
np.random.seed(42)

dummy_clf = DummyClassifier(strategy="most_frequent")
dummy_clf.fit(traindf['review'], traindf['label'])

preds = dummy_clf.predict(valdf['review'])

base_acc = accuracy_score(valdf['label'], preds)
base_rocauc = roc_auc_score(valdf['label'], preds)

print("accuracy: " , base_acc)
print("ROC AUC: ", base_rocauc)
# Out:
# accuracy:  0.7692647383528373
# ROC AUC:  0.5

# %%
# %%writefile model.py
# TODO: modify this custom model to your liking. Check out this tutorial for more on this class: https://outerbounds.com/docs/nlp-tutorial-L2/
# TODO: train the model on traindf.
# TODO: score the model on valdf with _the same_ 2D metric space you used in previous cell.
# TODO: test your model works by importing the model module in notebook cells, and trying to fit traindf and score predictions on the valdf data!

import tensorflow as tf
from tensorflow.keras import layers, optimizers, regularizers
from sklearn.base import BaseEstimator, ClassifierMixin
from sklearn.metrics import accuracy_score, roc_auc_score
from sklearn.feature_extraction.text import CountVectorizer

from dataclasses import dataclass, asdict

@dataclass
class ModelResult:
    "A custom struct for storing model evaluation results."
    name: None
    params: None
    pathspec: None
    acc: None
    rocauc: None

class NbowModel():
    def __init__(self, vocab_sz):

        self.vocab_sz = vocab_sz

        # Instantiate the CountVectorizer
        self.cv = CountVectorizer(
            min_df=.005, max_df = .75, stop_words='english', 
            strip_accents='ascii', max_features=self.vocab_sz
        )

        # Define the keras model
        inputs = tf.keras.Input(shape=(self.vocab_sz,), 
                                name='input')
        x = layers.Dropout(0.10)(inputs)
        x = layers.Dense(
            15, activation="relu",
            kernel_regularizer=regularizers.L1L2(l1=1e-5, l2=1e-4)
        )(x)
        predictions = layers.Dense(1, activation="sigmoid",)(x)
        self.model = tf.keras.Model(inputs, predictions)
        opt = optimizers.Adam(learning_rate=0.002)
        self.model.compile(loss="binary_crossentropy", 
                           optimizer=opt, metrics=["accuracy"])

    def fit(self, X, y):
        print(X.shape)
        print(X[0])
        res = self.cv.fit_transform(X).toarray()
        self.model.fit(x=res, y=y, batch_size=32, 
                       epochs=10, validation_split=.2)
    
    def predict(self, X):
        print(X.shape)
        print(X[0])
        res = self.cv.transform(X).toarray()
        return self.model.predict(res)
    
    def eval_acc(self, X, labels, threshold=.5):
        return accuracy_score(labels, 
                              self.predict(X) > threshold)
    
    def eval_rocauc(self, X, labels):
        return roc_auc_score(labels,  self.predict(X))

    @property
    def model_dict(self): 
        return {'vectorizer':self.cv, 'model': self.model}

    @classmethod
    def from_dict(cls, model_dict):
        "Get Model from dictionary"
        nbow_model = cls(len(
            model_dict['vectorizer'].vocabulary_
        ))
        nbow_model.model = model_dict['model']
        nbow_model.cv = model_dict['vectorizer']
        return nbow_model
# Out:
# Overwriting model.py

# %%
# %%writefile baseline_challenge.py
# TODO: In this cell, write your BaselineChallenge flow in the baseline_challenge.py file.

from metaflow import FlowSpec, step, Flow, current, Parameter, IncludeFile, card, current
from metaflow.cards import Table, Markdown, Artifact, Image
import numpy as np 
from dataclasses import dataclass, asdict

labeling_function = lambda row: 1 if row['rating']>=4 else 0

from model import ModelResult

class BaselineChallenge(FlowSpec):

    split_size = Parameter('split-sz', default=0.2)
    data = IncludeFile('data', default='../data/Womens Clothing E-Commerce Reviews.csv')
    kfold = Parameter('k', default=5)
    scoring = Parameter('scoring', default='accuracy')

    @step
    def start(self):

        import pandas as pd
        import io 
        from sklearn.model_selection import train_test_split
        
        # load dataset packaged with the flow.
        # this technique is convenient when working with small datasets that need to move to remove tasks.
        df = pd.read_csv(io.StringIO(self.data), index_col = 0)
        # TODO: load the data. 
        # Look up a few lines to the IncludeFile('data', default='Womens Clothing E-Commerce Reviews.csv'). 
        # You can find documentation on IncludeFile here: https://docs.metaflow.org/scaling/data#data-in-local-files

        # filter down to reviews and labels 
        df.columns = ["_".join(name.lower().strip().split()) for name in df.columns]
        df = df[~df.review_text.isna()]
        df['review'] = df['review_text'].astype('str')
        _has_review_df = df[df['review_text'] != 'nan']
        reviews = _has_review_df['review_text']
        labels = _has_review_df.apply(labeling_function, axis=1)
        self.df = pd.DataFrame({'label': labels, **_has_review_df})

        # split the data 80/20, or by using the flow's split-sz CLI argument
        _df = pd.DataFrame({'review': reviews, 'label': labels})
        self.traindf, self.valdf = train_test_split(_df, test_size=self.split_size)
        print(f'num of rows in train set: {self.traindf.shape[0]}')
        print(f'num of rows in validation set: {self.valdf.shape[0]}')

        self.next(self.baseline, self.model)

    @step
    def baseline(self):
        "Compute the baseline"

        from sklearn.metrics import accuracy_score, roc_auc_score
        self._name = "baseline"
        params = "Always predict 1"
        pathspec = f"{current.flow_name}/{current.run_id}/{current.step_name}/{current.task_id}"

        import numpy as np
        from sklearn.dummy import DummyClassifier
        from sklearn.metrics import accuracy_score, roc_auc_score, confusion_matrix
        np.random.seed(42)
        
        dummy_clf = DummyClassifier(strategy="most_frequent")
        dummy_clf.fit(self.traindf['review'], self.traindf['label'])
        
        predictions = dummy_clf.predict(self.valdf['review'])

        acc = accuracy_score(self.valdf['label'], predictions)
        rocauc = roc_auc_score(self.valdf['label'], predictions)
 
        self.result = ModelResult("Baseline", params, pathspec, acc, rocauc)
        #self.result_serialized = asdict(ModelResult("Baseline", params, pathspec, acc, rocauc))
        
        self.next(self.aggregate)

    @step
    def model(self):

        # TODO: import your model if it is defined in another file.
        from model import NbowModel

        self._name = "model"
        # NOTE: If you followed the link above to find a custom model implementation, 
            # you will have noticed your model's vocab_sz hyperparameter.
            # Too big of vocab_sz causes an error. Can you explain why? 
        self.hyperparam_set = [{'vocab_sz': 100}, {'vocab_sz': 300}, {'vocab_sz': 500}]  
        pathspec = f"{current.flow_name}/{current.run_id}/{current.step_name}/{current.task_id}"

        self.results = []
        self.results_serialized = []
        for params in self.hyperparam_set:
            model = NbowModel(**params) 
            model.fit(X=self.traindf['review'].values, y=self.traindf['label'])
            acc = model.eval_acc(X=self.valdf['review'].values, labels=self.valdf['label']) 
            rocauc = model.eval_rocauc(X=self.valdf['review'].values, labels=self.valdf['label'])
            self.results.append(ModelResult(f"NbowModel - vocab_sz: {params['vocab_sz']}", params, pathspec, acc, rocauc))
            #self.results_serialized.append(asdict(ModelResult(f"NbowModel - vocab_sz: {params['vocab_sz']}", params, pathspec, acc, rocauc)))
        self.next(self.aggregate)

    @step
    def aggregate(self, inputs):
        pass
        self.next(self.end)

    @step
    def end(self):
        pass

if __name__ == '__main__':
    BaselineChallenge()
# Out:
# Overwriting baseline_challenge.py

# %%
! python baseline_challenge.py run --data /home/workspace/workspaces/full-stack-ml-metaflow-corise-week-2/data/Womens\ Clothing\ E-Commerce\ Reviews.csv
# Out:
# Metaflow 2.8.3.1+ob(v1) executing BaselineChallenge for user:sandbox
# Validating your flow...
#     The graph looks good!
# Running pylint...
#     Pylint is happy!
# Including file /home/workspace/workspaces/full-stack-ml-metaflow-corise-week-2/data/Womens Clothing E-Commerce Reviews.csv of size 8MB
# 2023-05-10 06:17:24.273 Workflow starting (run-id 102), see it in the UI at https://ui-pw-673206860.outerbounds.dev/BaselineChallenge/102
# 2023-05-10 06:17:24.463 [102/start/505 (pid 779)] Task is starting.
# 2023-05-10 06:17:28.772 [102/start/505 (pid 779)] num of rows in train set: 18112
# 2023-05-10 06:17:31.602 [102/start/505 (pid 779)] num of rows in validation set: 4529
# 2023-05-10 06:17:31.869 [102/start/505 (pid 779)] Task finished successfully.
# 2023-05-10 06:17:32.278 [102/baseline/506 (pid 885)] Task is starting.
# 2023-05-10 06:17:32.477 [102/model/507 (pid 888)] Task is starting.
# 2023-05-10 06:17:35.879 [102/model/507 (pid 888)] 2023-05-10 06:17:35.879854: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 AVX512F FMA
# 2023-05-10 06:17:36.027 [102/model/507 (pid 888)] (18112,)
# 2023-05-10 06:17:37.414 [102/model/507 (pid 888)] To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-05-10 06:17:37.415 [102/model/507 (pid 888)] 2023-05-10 06:17:37.414862: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:116] None of the MLIR optimization passes are enabled (registered 2)
# 2023-05-10 06:17:37.485 [102/model/507 (pid 888)] 2023-05-10 06:17:37.483448: I tensorflow/core/platform/profile_utils/cpu_utils.cc:112] CPU Frequency: 2500000000 Hz
# 2023-05-10 06:17:37.583 [102/model/507 (pid 888)] Simple blazer with cute details - buttons on the back and lining. this will look good both in the office over over a pair of jeans and booties. i was able to go with the regular size (instead of petite) because i will wear with the sleeve rolled up.
# 2023-05-10 06:17:37.583 [102/model/507 (pid 888)] Epoch 1/10
# 453/453 [==============================] - 1s 2ms/step - loss: 0.5083 - accuracy: 0.7740 - val_loss: 0.4104 - val_accuracy: 0.81596375 - accuracy: 0.62
# 2023-05-10 06:17:38.896 [102/model/507 (pid 888)] Epoch 2/10
# 453/453 [==============================] - 0s 1ms/step - loss: 0.4136 - accuracy: 0.8131 - val_loss: 0.4070 - val_accuracy: 0.813437 - accuracy: 0.78
# 2023-05-10 06:17:39.640 [102/baseline/506 (pid 885)] Task finished successfully.
# 2023-05-10 06:17:39.857 [102/model/507 (pid 888)] Epoch 3/10
# 453/453 [==============================] - 0s 811us/step - loss: 0.4111 - accuracy: 0.8163 - val_loss: 0.4065 - val_accuracy: 0.8178 - accuracy: 0.87
# 2023-05-10 06:17:39.865 [102/model/507 (pid 888)] Epoch 4/10
# 453/453 [==============================] - 0s 806us/step - loss: 0.4107 - accuracy: 0.8155 - val_loss: 0.4029 - val_accuracy: 0.8184 - accuracy: 0.81
# 2023-05-10 06:17:40.130 [102/model/507 (pid 888)] Epoch 5/10
# 453/453 [==============================] - 0s 810us/step - loss: 0.4074 - accuracy: 0.8163 - val_loss: 0.4041 - val_accuracy: 0.8209 - accuracy: 0.81
# 2023-05-10 06:17:40.498 [102/model/507 (pid 888)] Epoch 6/10
# 453/453 [==============================] - 0s 799us/step - loss: 0.4019 - accuracy: 0.8208 - val_loss: 0.4037 - val_accuracy: 0.8181 - accuracy: 0.96
# 2023-05-10 06:17:40.861 [102/model/507 (pid 888)] Epoch 7/10
# 453/453 [==============================] - 0s 830us/step - loss: 0.3988 - accuracy: 0.8197 - val_loss: 0.4031 - val_accuracy: 0.8181 - accuracy: 0.81
# 2023-05-10 06:17:41.237 [102/model/507 (pid 888)] Epoch 8/10
# 453/453 [==============================] - 0s 798us/step - loss: 0.4051 - accuracy: 0.8177 - val_loss: 0.4023 - val_accuracy: 0.8178 - accuracy: 0.93
# 2023-05-10 06:17:41.600 [102/model/507 (pid 888)] Epoch 9/10
# 453/453 [==============================] - 0s 792us/step - loss: 0.4007 - accuracy: 0.8195 - val_loss: 0.4047 - val_accuracy: 0.8173 - accuracy: 0.84
# 2023-05-10 06:17:41.959 [102/model/507 (pid 888)] Epoch 10/10
# 453/453 [==============================] - 0s 804us/step - loss: 0.4000 - accuracy: 0.8244 - val_loss: 0.4036 - val_accuracy: 0.8192 - accuracy: 0.84
# 2023-05-10 06:17:42.416 [102/model/507 (pid 888)] (4529,)
# 2023-05-10 06:17:42.664 [102/model/507 (pid 888)] I can't say enough about this sweater! it light, delicate, soft, vintage chic........i could go on and on! buy it already!!!
# 2023-05-10 06:17:42.664 [102/model/507 (pid 888)] (4529,)
# 2023-05-10 06:17:42.888 [102/model/507 (pid 888)] I can't say enough about this sweater! it light, delicate, soft, vintage chic........i could go on and on! buy it already!!!
# 2023-05-10 06:17:42.888 [102/model/507 (pid 888)] (18112,)
# 2023-05-10 06:17:43.589 [102/model/507 (pid 888)] Simple blazer with cute details - buttons on the back and lining. this will look good both in the office over over a pair of jeans and booties. i was able to go with the regular size (instead of petite) because i will wear with the sleeve rolled up.
# 2023-05-10 06:17:43.589 [102/model/507 (pid 888)] Epoch 1/10
# 453/453 [==============================] - 1s 1ms/step - loss: 0.4761 - accuracy: 0.7861 - val_loss: 0.3390 - val_accuracy: 0.85107068 - accuracy: 0.53
# 2023-05-10 06:17:44.377 [102/model/507 (pid 888)] Epoch 2/10
# 453/453 [==============================] - 0s 918us/step - loss: 0.3521 - accuracy: 0.8489 - val_loss: 0.3386 - val_accuracy: 0.8556 - accuracy: 0.90
# 2023-05-10 06:17:44.794 [102/model/507 (pid 888)] Epoch 3/10
# 453/453 [==============================] - 0s 920us/step - loss: 0.3451 - accuracy: 0.8542 - val_loss: 0.3350 - val_accuracy: 0.8515 - accuracy: 0.87
# 2023-05-10 06:17:45.211 [102/model/507 (pid 888)] Epoch 4/10
# 453/453 [==============================] - 0s 908us/step - loss: 0.3361 - accuracy: 0.8607 - val_loss: 0.3318 - val_accuracy: 0.8526 - accuracy: 0.93
# 2023-05-10 06:17:45.623 [102/model/507 (pid 888)] Epoch 5/10
# 453/453 [==============================] - 0s 907us/step - loss: 0.3229 - accuracy: 0.8637 - val_loss: 0.3332 - val_accuracy: 0.8545 - accuracy: 0.87
# 2023-05-10 06:17:46.035 [102/model/507 (pid 888)] Epoch 6/10
# 453/453 [==============================] - 0s 896us/step - loss: 0.3211 - accuracy: 0.8652 - val_loss: 0.3351 - val_accuracy: 0.8584 - accuracy: 0.84
# 2023-05-10 06:17:46.442 [102/model/507 (pid 888)] Epoch 7/10
# 453/453 [==============================] - 0s 916us/step - loss: 0.3215 - accuracy: 0.8656 - val_loss: 0.3359 - val_accuracy: 0.8570 - accuracy: 0.84
# 2023-05-10 06:17:46.858 [102/model/507 (pid 888)] Epoch 8/10
# 453/453 [==============================] - 0s 908us/step - loss: 0.3159 - accuracy: 0.8711 - val_loss: 0.3366 - val_accuracy: 0.8559 - accuracy: 0.90
# 2023-05-10 06:17:47.270 [102/model/507 (pid 888)] Epoch 9/10
# 453/453 [==============================] - 0s 896us/step - loss: 0.3178 - accuracy: 0.8714 - val_loss: 0.3391 - val_accuracy: 0.8576 - accuracy: 0.96
# 2023-05-10 06:17:47.676 [102/model/507 (pid 888)] Epoch 10/10
# 453/453 [==============================] - 0s 907us/step - loss: 0.3112 - accuracy: 0.8741 - val_loss: 0.3430 - val_accuracy: 0.8540 - accuracy: 0.87
# 2023-05-10 06:17:48.090 [102/model/507 (pid 888)] (4529,)
# 2023-05-10 06:17:48.327 [102/model/507 (pid 888)] I can't say enough about this sweater! it light, delicate, soft, vintage chic........i could go on and on! buy it already!!!
# 2023-05-10 06:17:48.327 [102/model/507 (pid 888)] (4529,)
# 2023-05-10 06:17:48.567 [102/model/507 (pid 888)] I can't say enough about this sweater! it light, delicate, soft, vintage chic........i could go on and on! buy it already!!!
# 2023-05-10 06:17:48.567 [102/model/507 (pid 888)] (18112,)
# 2023-05-10 06:17:49.303 [102/model/507 (pid 888)] Simple blazer with cute details - buttons on the back and lining. this will look good both in the office over over a pair of jeans and booties. i was able to go with the regular size (instead of petite) because i will wear with the sleeve rolled up.
# 2023-05-10 06:17:49.303 [102/model/507 (pid 888)] Epoch 1/10
# 453/453 [==============================] - 1s 1ms/step - loss: 0.4621 - accuracy: 0.7917 - val_loss: 0.3221 - val_accuracy: 0.85876701 - accuracy: 0.65
# 2023-05-10 06:17:50.131 [102/model/507 (pid 888)] Epoch 2/10
# 453/453 [==============================] - 0s 1ms/step - loss: 0.3341 - accuracy: 0.8611 - val_loss: 0.3197 - val_accuracy: 0.863948 - accuracy: 0.90
# 2023-05-10 06:17:50.598 [102/model/507 (pid 888)] Epoch 3/10
# 453/453 [==============================] - 0s 997us/step - loss: 0.3234 - accuracy: 0.8655 - val_loss: 0.3204 - val_accuracy: 0.8579 - accuracy: 0.90
# 2023-05-10 06:17:51.050 [102/model/507 (pid 888)] Epoch 4/10
# 453/453 [==============================] - 0s 1ms/step - loss: 0.3118 - accuracy: 0.8677 - val_loss: 0.3173 - val_accuracy: 0.862024 - accuracy: 0.81
# 2023-05-10 06:17:51.505 [102/model/507 (pid 888)] Epoch 5/10
# 453/453 [==============================] - 0s 1ms/step - loss: 0.3096 - accuracy: 0.8739 - val_loss: 0.3184 - val_accuracy: 0.860140 - accuracy: 0.68
# 2023-05-10 06:17:51.959 [102/model/507 (pid 888)] Epoch 6/10
# 453/453 [==============================] - 0s 1ms/step - loss: 0.2930 - accuracy: 0.8823 - val_loss: 0.3202 - val_accuracy: 0.863486 - accuracy: 0.90
# 2023-05-10 06:17:52.417 [102/model/507 (pid 888)] Epoch 7/10
# 453/453 [==============================] - 0s 1000us/step - loss: 0.2923 - accuracy: 0.8782 - val_loss: 0.3241 - val_accuracy: 0.8606- accuracy: 0.93
# 2023-05-10 06:17:52.871 [102/model/507 (pid 888)] Epoch 8/10
# 453/453 [==============================] - 0s 1ms/step - loss: 0.2840 - accuracy: 0.8859 - val_loss: 0.3310 - val_accuracy: 0.858727 - accuracy: 0.90
# 2023-05-10 06:17:53.328 [102/model/507 (pid 888)] Epoch 9/10
# 453/453 [==============================] - 0s 1ms/step - loss: 0.2763 - accuracy: 0.8898 - val_loss: 0.3371 - val_accuracy: 0.853717 - accuracy: 0.96
# 2023-05-10 06:17:53.787 [102/model/507 (pid 888)] Epoch 10/10
# 453/453 [==============================] - 0s 1ms/step - loss: 0.2659 - accuracy: 0.9006 - val_loss: 0.3410 - val_accuracy: 0.859050 - accuracy: 0.93
# 2023-05-10 06:17:54.249 [102/model/507 (pid 888)] (4529,)
# 2023-05-10 06:17:54.495 [102/model/507 (pid 888)] I can't say enough about this sweater! it light, delicate, soft, vintage chic........i could go on and on! buy it already!!!
# 2023-05-10 06:17:54.495 [102/model/507 (pid 888)] (4529,)
# 2023-05-10 06:17:57.331 [102/model/507 (pid 888)] I can't say enough about this sweater! it light, delicate, soft, vintage chic........i could go on and on! buy it already!!!
# 2023-05-10 06:17:57.581 [102/model/507 (pid 888)] Task finished successfully.
# 2023-05-10 06:17:57.986 [102/aggregate/508 (pid 1209)] Task is starting.
# 2023-05-10 06:18:02.923 [102/aggregate/508 (pid 1209)] Task finished successfully.
# 2023-05-10 06:18:03.304 [102/end/509 (pid 1266)] Task is starting.
# 2023-05-10 06:18:07.739 [102/end/509 (pid 1266)] Task finished successfully.
# 2023-05-10 06:18:07.850 Done! See the run in the UI at https://ui-pw-673206860.outerbounds.dev/BaselineChallenge/102

# %% [markdown]
# ## Task 2: Anticipating Failure in Your Machine Learning Project
#
# In this task, you'll practice anticipating potential failure modes in a sentiment analysis classifier and develop strategies to mitigate them. Here's what you'll need to do:
# ### Step 1: Identify Potential Failure Modes
#
# The first step in anticipating failure in your machine learning project is to identify potential failure modes. Start by brainstorming ways in which your project could fail from an engineering point of view. For example, your model could overfit to the training data or suffer from data bias.
#
# ##### significant change class skew in daily data
# ##### data bias
# ##### discrimination like gender bias, socio-economic bias, racial bias etc
# ##### label error
# ##### sensitivity to data noise
# ##### sensitivity to label noise
# ##### underfitting / over fitting
# ##### sudden large change in driving metrics
# ##### choice of metrics
# #####
#
#
# ### Step 2: Develop Strategies to Mitigate Failure Modes
#
# Once you've identified potential failure modes, the next step is to develop strategies to mitigate them. Think about what measures you could take to fix the issue if it were to occur. For example, if your model is overfitting to the training data, you could try regularization techniques such as L1 or L2 regularization to reduce the complexity of the model.
#
#
# ##### check class skew in daily data
# ##### check data bias : check population bias because of nature of data presentation/collection (like 1st slot getting very high clicks independent of content). Fix it if possible, using methods like Inverse Propensity Weighing (IPW), Doubly Robust (DR) estimators etc on loss like click prediction loss and rate features like CTR.
# ##### check discrimination : check for gender bias, socio-economic bias, racial bias etc
# ##### find label error using label correction libraries
# ##### model sensitivity to data noise: data augmentation
# ##### analysis on model sensitivity to label noise
# ##### check underfitting / over fitting: increase model complexity / add regularisation
# ##### if learning not happening use batch norm and stuff for improve loss surface or gradient magnitude / co-variate shift
# ##### gaurd rails (sudden large change in metrics): have alerts for metrics moving out of gaurd rails
# ##### run offline test to validate improvement (if possible do counterfactual evaluation to measure improvement)
#
#
# ### Step 3: Plan Ahead to Avoid Failure Modes
#
# Finally, it's important to plan ahead to avoid potential failure modes in the first place. Think about what you could have done initially to avoid these failure modes. For example, you could have collected a diverse set of training data to reduce data bias or experimented with different model architectures to find the best solution for your problem.
#
# The key to anticipating failure in your machine learning project is to be proactive rather than reactive. By identifying potential failure modes ahead of time and developing strategies to mitigate them, you'll be better equipped to build a successful machine learning project.

# %% [markdown]
# ## Task 3: Visualizing ML Results with MF Cards
# Now it is time to iterate. Extend the flow in your `baseline_challenge.py` file to include a step that aggregates all of the results from hyperparameter tuning jobs, and logs results and a data visualiation in a Metaflow card.

# %%
# %%writefile baseline_challenge_1.py
# TODO: In this cell, write your BaselineChallenge flow in the baseline_challenge.py file.

from metaflow import FlowSpec, step, Flow, current, Parameter, IncludeFile, card, current
from metaflow.cards import Table, Markdown, Artifact, Image
import numpy as np 
from dataclasses import dataclass, asdict

labeling_function = lambda row: 1 if row['rating']>=4 else 0

from model import ModelResult

class BaselineChallenge(FlowSpec):

    split_size = Parameter('split-sz', default=0.2)
    data = IncludeFile('data', default='Womens Clothing E-Commerce Reviews.csv')
    kfold = Parameter('k', default=5)
    scoring = Parameter('scoring', default='accuracy')
    @step
    def start(self):

        import pandas as pd
        import io 
        from sklearn.model_selection import train_test_split
        
        # load dataset packaged with the flow.
        # this technique is convenient when working with small datasets that need to move to remove tasks.
        df = pd.read_csv(io.StringIO(self.data), index_col = 0)
        # TODO: load the data. 
        # Look up a few lines to the IncludeFile('data', default='Womens Clothing E-Commerce Reviews.csv'). 
        # You can find documentation on IncludeFile here: https://docs.metaflow.org/scaling/data#data-in-local-files

        # filter down to reviews and labels 
        df.columns = ["_".join(name.lower().strip().split()) for name in df.columns]
        df = df[~df.review_text.isna()]
        df['review'] = df['review_text'].astype('str')
        _has_review_df = df[df['review_text'] != 'nan']
        reviews = _has_review_df['review_text']
        labels = _has_review_df.apply(labeling_function, axis=1)
        self.df = pd.DataFrame({'label': labels, **_has_review_df})

        # split the data 80/20, or by using the flow's split-sz CLI argument
        _df = pd.DataFrame({'review': reviews, 'label': labels})
        self.traindf, self.valdf = train_test_split(_df, test_size=self.split_size)
        print(f'num of rows in train set: {self.traindf.shape[0]}')
        print(f'num of rows in validation set: {self.valdf.shape[0]}')

        self.next(self.baseline, self.model)

    @step
    def baseline(self):
        "Compute the baseline"

        self._name = "baseline"
        params = "Always predict 1"
        pathspec = f"{current.flow_name}/{current.run_id}/{current.step_name}/{current.task_id}"

        import numpy as np
        from sklearn.dummy import DummyClassifier
        from sklearn.metrics import accuracy_score, roc_auc_score, confusion_matrix
        np.random.seed(42)
        
        dummy_clf = DummyClassifier(strategy="most_frequent")
        dummy_clf.fit(self.traindf['review'], self.traindf['label'])
        
        predictions = dummy_clf.predict(self.valdf['review'])

        acc = accuracy_score(self.valdf['label'], predictions)
        rocauc = roc_auc_score(self.valdf['label'], predictions)
 
        self.result = ModelResult("Baseline", params, pathspec, acc, rocauc)
        #self.result_serialized = asdict(ModelResult("Baseline", params, pathspec, acc, rocauc))
        self.next(self.aggregate)

    @step
    def model(self):

        # TODO: import your model if it is defined in another file.
        from model import NbowModel

        self._name = "model"
        # NOTE: If you followed the link above to find a custom model implementation, 
            # you will have noticed your model's vocab_sz hyperparameter.
            # Too big of vocab_sz causes an error. Can you explain why? 
        self.hyperparam_set = [{'vocab_sz': 100}, {'vocab_sz': 300}, {'vocab_sz': 500}]  
        pathspec = f"{current.flow_name}/{current.run_id}/{current.step_name}/{current.task_id}"

        self.results = []
        self.results_serialized = []
        for params in self.hyperparam_set:
            model = NbowModel(**params) 
            model.fit(X=self.traindf['review'].values, y=self.traindf['label'])
            acc = model.eval_acc(X=self.valdf['review'].values, labels=self.valdf['label']) 
            rocauc = model.eval_rocauc(X=self.valdf['review'].values, labels=self.valdf['label'])
            self.results.append(ModelResult(f"NbowModel - vocab_sz: {params['vocab_sz']}", params, pathspec, acc, rocauc))
            #self.results_serialized.append(asdict(ModelResult(f"NbowModel - vocab_sz: {params['vocab_sz']}", params, pathspec, acc, rocauc)))
        self.next(self.aggregate)

    def add_one(self, rows, result, df):
        "A helper function to load results."
        rows.append([
            Markdown(result.name),
            Artifact(result.params),
            Artifact(result.pathspec),
            Artifact(result.acc),
            Artifact(result.rocauc)
        ])
        df['name'].append(result.name)
        df['accuracy'].append(result.acc)
        return rows, df

    @card(type="corise") # TODO: Set your card type to "corise". 
            # I wonder what other card types there are?
            # https://docs.metaflow.org/metaflow/visualizing-results
            # https://github.com/outerbounds/metaflow-card-altair/blob/main/altairflow.py
    @step
    def aggregate(self, inputs):

        import seaborn as sns
        import matplotlib.pyplot as plt
        from matplotlib import rcParams 
        rcParams.update({'figure.autolayout': True})

        rows = []
        violin_plot_df = {'name': [], 'accuracy': []}
        for task in inputs:
            if task._name == "model": 
                for result in task.results:
                    print(result)
                    rows, violin_plot_df = self.add_one(rows, result, violin_plot_df)
            elif task._name == "baseline":
                print(task.result)
                rows, violin_plot_df = self.add_one(rows, task.result, violin_plot_df)
            else:
                raise ValueError("Unknown task._name type. Cannot parse results.")
            
        current.card.append(Markdown("# All models from this flow run"))

        # TODO: Add a Table of the results to your card! 
        current.card.append(
            Table(
                rows, # TODO: What goes here to populate the Table in the card? 
                headers=["Model name", "Params", "Task pathspec", "Accuracy", "ROCAUC"]
            )
        )
        
        fig, ax = plt.subplots(1,1)
        plt.xticks(rotation=40)
        sns.violinplot(data=violin_plot_df, x="name", y="accuracy", ax=ax)
        
        # TODO: Append the matplotlib fig to the card
        # Docs: https://docs.metaflow.org/metaflow/visualizing-results/easy-custom-reports-with-card-components#showing-plots
        current.card.append(Image.from_matplotlib(fig))
        #self.merge_artifacts(inputs, include=['result_serialized', 'results_serialized'])
        self.next(self.end)

    @step
    def end(self):
        pass

if __name__ == '__main__':
    BaselineChallenge()
# Out:
# Overwriting baseline_challenge_1.py

# %%
! python baseline_challenge_1.py run --data /home/workspace/workspaces/full-stack-ml-metaflow-corise-week-2/data/Womens\ Clothing\ E-Commerce\ Reviews.csv
# Out:
# Metaflow 2.8.3.1+ob(v1) executing BaselineChallenge for user:sandbox
# Validating your flow...
#     The graph looks good!
# Running pylint...
#     Pylint is happy!
# Including file /home/workspace/workspaces/full-stack-ml-metaflow-corise-week-2/data/Womens Clothing E-Commerce Reviews.csv of size 8MB
# 2023-05-10 06:15:14.734 Workflow starting (run-id 101), see it in the UI at https://ui-pw-673206860.outerbounds.dev/BaselineChallenge/101
# 2023-05-10 06:15:14.928 [101/start/499 (pid 32605)] Task is starting.
# 2023-05-10 06:15:19.264 [101/start/499 (pid 32605)] num of rows in train set: 18112
# 2023-05-10 06:15:22.055 [101/start/499 (pid 32605)] num of rows in validation set: 4529
# 2023-05-10 06:15:22.307 [101/start/499 (pid 32605)] Task finished successfully.
# 2023-05-10 06:15:22.605 [101/baseline/500 (pid 32711)] Task is starting.
# 2023-05-10 06:15:22.759 [101/model/501 (pid 32714)] Task is starting.
# 2023-05-10 06:15:26.136 [101/model/501 (pid 32714)] 2023-05-10 06:15:26.136511: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 AVX512F FMA
# 2023-05-10 06:15:26.260 [101/model/501 (pid 32714)] (18112,)
# 2023-05-10 06:15:27.706 [101/model/501 (pid 32714)] To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-05-10 06:15:27.706 [101/model/501 (pid 32714)] 2023-05-10 06:15:27.706665: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:116] None of the MLIR optimization passes are enabled (registered 2)
# 2023-05-10 06:15:27.725 [101/model/501 (pid 32714)] 2023-05-10 06:15:27.725871: I tensorflow/core/platform/profile_utils/cpu_utils.cc:112] CPU Frequency: 2500000000 Hz
# 2023-05-10 06:15:27.735 [101/model/501 (pid 32714)] Tried this skirt on in the store and loved it...so pretty,feminine and versatile,except for the color.. although its a gorgeous color and i do love red,how often do people wear red skirts? i would have snatched it up if it were offered in other colors. unlike the other reviewer,i think the ruching is great as it gives you the option to wear the skirt higher or lower on your waist and adds the axtra interest factor. as this would be a totally frivolous buy,i'm going to resist and try to wait for
# 2023-05-10 06:15:27.735 [101/model/501 (pid 32714)] Epoch 1/10
# 453/453 [==============================] - 1s 2ms/step - loss: 0.5192 - accuracy: 0.7538 - val_loss: 0.4108 - val_accuracy: 0.82090.8404 - accuracy: 0.37
# 2023-05-10 06:15:29.213 [101/model/501 (pid 32714)] Epoch 2/10
# 453/453 [==============================] - 1s 1ms/step - loss: 0.4291 - accuracy: 0.8049 - val_loss: 0.4114 - val_accuracy: 0.81535030 - accuracy: 0.81
# 2023-05-10 06:15:29.735 [101/model/501 (pid 32714)] Epoch 3/10
# 453/453 [==============================] - 0s 847us/step - loss: 0.4163 - accuracy: 0.8141 - val_loss: 0.4103 - val_accuracy: 0.814811 - accuracy: 0.71
# 2023-05-10 06:15:30.354 [101/baseline/500 (pid 32711)] Task finished successfully.
# 2023-05-10 06:15:30.512 [101/model/501 (pid 32714)] Epoch 4/10
# 453/453 [==============================] - 0s 795us/step - loss: 0.4096 - accuracy: 0.8144 - val_loss: 0.4074 - val_accuracy: 0.821404 - accuracy: 0.84
# 2023-05-10 06:15:30.531 [101/model/501 (pid 32714)] Epoch 5/10
# 453/453 [==============================] - 0s 795us/step - loss: 0.4174 - accuracy: 0.8132 - val_loss: 0.4094 - val_accuracy: 0.818981 - accuracy: 0.84
# 2023-05-10 06:15:30.841 [101/model/501 (pid 32714)] Epoch 6/10
# 453/453 [==============================] - 0s 820us/step - loss: 0.4057 - accuracy: 0.8186 - val_loss: 0.4097 - val_accuracy: 0.819830 - accuracy: 0.81
# 2023-05-10 06:15:31.213 [101/model/501 (pid 32714)] Epoch 7/10
# 453/453 [==============================] - 0s 804us/step - loss: 0.4044 - accuracy: 0.8219 - val_loss: 0.4108 - val_accuracy: 0.821159 - accuracy: 0.84
# 2023-05-10 06:15:31.578 [101/model/501 (pid 32714)] Epoch 8/10
# 453/453 [==============================] - 0s 809us/step - loss: 0.4061 - accuracy: 0.8192 - val_loss: 0.4125 - val_accuracy: 0.818475 - accuracy: 0.75
# 2023-05-10 06:15:31.946 [101/model/501 (pid 32714)] Epoch 9/10
# 453/453 [==============================] - 0s 789us/step - loss: 0.4027 - accuracy: 0.8214 - val_loss: 0.4138 - val_accuracy: 0.820917 - accuracy: 0.84
# 2023-05-10 06:15:32.304 [101/model/501 (pid 32714)] Epoch 10/10
# 453/453 [==============================] - 0s 786us/step - loss: 0.4026 - accuracy: 0.8213 - val_loss: 0.4139 - val_accuracy: 0.816767 - accuracy: 0.84
# 2023-05-10 06:15:32.752 [101/model/501 (pid 32714)] (4529,)
# 2023-05-10 06:15:33.004 [101/model/501 (pid 32714)] Another shirt i really wanted to love. i adore green but so few tops are made in this color. (please make more!!) however, this shirt didn't work for me. i think it's a matter of where your curves live. the shirt was true to size, but my boobs meant i was showing more cleavage than the model, and the top part felt more like a bib than embroidery. sad coz it is lovely and feels lovely on. probably a great shirt for different body types. would love to see more green clothing....
# 2023-05-10 06:15:33.004 [101/model/501 (pid 32714)] (4529,)
# 2023-05-10 06:15:33.223 [101/model/501 (pid 32714)] Another shirt i really wanted to love. i adore green but so few tops are made in this color. (please make more!!) however, this shirt didn't work for me. i think it's a matter of where your curves live. the shirt was true to size, but my boobs meant i was showing more cleavage than the model, and the top part felt more like a bib than embroidery. sad coz it is lovely and feels lovely on. probably a great shirt for different body types. would love to see more green clothing....
# 2023-05-10 06:15:33.223 [101/model/501 (pid 32714)] (18112,)
# 2023-05-10 06:15:33.914 [101/model/501 (pid 32714)] Tried this skirt on in the store and loved it...so pretty,feminine and versatile,except for the color.. although its a gorgeous color and i do love red,how often do people wear red skirts? i would have snatched it up if it were offered in other colors. unlike the other reviewer,i think the ruching is great as it gives you the option to wear the skirt higher or lower on your waist and adds the axtra interest factor. as this would be a totally frivolous buy,i'm going to resist and try to wait for
# 2023-05-10 06:15:33.914 [101/model/501 (pid 32714)] Epoch 1/10
# 453/453 [==============================] - 1s 1ms/step - loss: 0.4900 - accuracy: 0.7653 - val_loss: 0.3616 - val_accuracy: 0.84960.8073 - accuracy: 0.28
# 2023-05-10 06:15:34.685 [101/model/501 (pid 32714)] Epoch 2/10
# 453/453 [==============================] - 0s 916us/step - loss: 0.3598 - accuracy: 0.8485 - val_loss: 0.3596 - val_accuracy: 0.844925 - accuracy: 0.87
# 2023-05-10 06:15:35.101 [101/model/501 (pid 32714)] Epoch 3/10
# 453/453 [==============================] - 0s 891us/step - loss: 0.3446 - accuracy: 0.8580 - val_loss: 0.3543 - val_accuracy: 0.850775 - accuracy: 0.90
# 2023-05-10 06:15:35.505 [101/model/501 (pid 32714)] Epoch 4/10
# 453/453 [==============================] - 0s 895us/step - loss: 0.3426 - accuracy: 0.8543 - val_loss: 0.3594 - val_accuracy: 0.849850 - accuracy: 0.71
# 2023-05-10 06:15:35.912 [101/model/501 (pid 32714)] Epoch 5/10
# 453/453 [==============================] - 0s 888us/step - loss: 0.3303 - accuracy: 0.8628 - val_loss: 0.3598 - val_accuracy: 0.850189 - accuracy: 0.87
# 2023-05-10 06:15:36.315 [101/model/501 (pid 32714)] Epoch 6/10
# 453/453 [==============================] - 0s 908us/step - loss: 0.3213 - accuracy: 0.8651 - val_loss: 0.3567 - val_accuracy: 0.852903 - accuracy: 0.87
# 2023-05-10 06:15:36.727 [101/model/501 (pid 32714)] Epoch 7/10
# 453/453 [==============================] - 0s 908us/step - loss: 0.3211 - accuracy: 0.8678 - val_loss: 0.3620 - val_accuracy: 0.846871 - accuracy: 0.75
# 2023-05-10 06:15:37.139 [101/model/501 (pid 32714)] Epoch 8/10
# 453/453 [==============================] - 0s 918us/step - loss: 0.3079 - accuracy: 0.8783 - val_loss: 0.3629 - val_accuracy: 0.848275 - accuracy: 0.90
# 2023-05-10 06:15:37.556 [101/model/501 (pid 32714)] Epoch 9/10
# 453/453 [==============================] - 0s 907us/step - loss: 0.3010 - accuracy: 0.8794 - val_loss: 0.3659 - val_accuracy: 0.846819 - accuracy: 0.68
# 2023-05-10 06:15:37.967 [101/model/501 (pid 32714)] Epoch 10/10
# 453/453 [==============================] - 0s 903us/step - loss: 0.2943 - accuracy: 0.8812 - val_loss: 0.3633 - val_accuracy: 0.850431 - accuracy: 0.87
# 2023-05-10 06:15:38.380 [101/model/501 (pid 32714)] (4529,)
# 2023-05-10 06:15:38.617 [101/model/501 (pid 32714)] Another shirt i really wanted to love. i adore green but so few tops are made in this color. (please make more!!) however, this shirt didn't work for me. i think it's a matter of where your curves live. the shirt was true to size, but my boobs meant i was showing more cleavage than the model, and the top part felt more like a bib than embroidery. sad coz it is lovely and feels lovely on. probably a great shirt for different body types. would love to see more green clothing....
# 2023-05-10 06:15:38.618 [101/model/501 (pid 32714)] (4529,)
# 2023-05-10 06:15:38.865 [101/model/501 (pid 32714)] Another shirt i really wanted to love. i adore green but so few tops are made in this color. (please make more!!) however, this shirt didn't work for me. i think it's a matter of where your curves live. the shirt was true to size, but my boobs meant i was showing more cleavage than the model, and the top part felt more like a bib than embroidery. sad coz it is lovely and feels lovely on. probably a great shirt for different body types. would love to see more green clothing....
# 2023-05-10 06:15:38.865 [101/model/501 (pid 32714)] (18112,)
# 2023-05-10 06:15:39.604 [101/model/501 (pid 32714)] Tried this skirt on in the store and loved it...so pretty,feminine and versatile,except for the color.. although its a gorgeous color and i do love red,how often do people wear red skirts? i would have snatched it up if it were offered in other colors. unlike the other reviewer,i think the ruching is great as it gives you the option to wear the skirt higher or lower on your waist and adds the axtra interest factor. as this would be a totally frivolous buy,i'm going to resist and try to wait for
# 2023-05-10 06:15:39.605 [101/model/501 (pid 32714)] Epoch 1/10
# 453/453 [==============================] - 1s 1ms/step - loss: 0.4817 - accuracy: 0.7672 - val_loss: 0.3488 - val_accuracy: 0.85590.7884 - accuracy: 0.31
# 2023-05-10 06:15:40.414 [101/model/501 (pid 32714)] Epoch 2/10
# 453/453 [==============================] - 0s 984us/step - loss: 0.3313 - accuracy: 0.8625 - val_loss: 0.3367 - val_accuracy: 0.858401 - accuracy: 0.90
# 2023-05-10 06:15:40.861 [101/model/501 (pid 32714)] Epoch 3/10
# 453/453 [==============================] - 0s 997us/step - loss: 0.3255 - accuracy: 0.8636 - val_loss: 0.3359 - val_accuracy: 0.864512 - accuracy: 0.87
# 2023-05-10 06:15:41.313 [101/model/501 (pid 32714)] Epoch 4/10
# 453/453 [==============================] - 0s 1ms/step - loss: 0.3077 - accuracy: 0.8746 - val_loss: 0.3403 - val_accuracy: 0.86122520 - accuracy: 0.87
# 2023-05-10 06:15:41.771 [101/model/501 (pid 32714)] Epoch 5/10
# 453/453 [==============================] - 0s 1ms/step - loss: 0.3032 - accuracy: 0.8769 - val_loss: 0.3400 - val_accuracy: 0.85762020 - accuracy: 0.93
# 2023-05-10 06:15:42.235 [101/model/501 (pid 32714)] Epoch 6/10
# 453/453 [==============================] - 0s 1ms/step - loss: 0.2903 - accuracy: 0.8810 - val_loss: 0.3408 - val_accuracy: 0.86033982 - accuracy: 0.78
# 2023-05-10 06:15:42.689 [101/model/501 (pid 32714)] Epoch 7/10
# 453/453 [==============================] - 0s 1ms/step - loss: 0.2736 - accuracy: 0.8947 - val_loss: 0.3494 - val_accuracy: 0.85671424 - accuracy: 0.96
# 2023-05-10 06:15:43.147 [101/model/501 (pid 32714)] Epoch 8/10
# 453/453 [==============================] - 0s 1ms/step - loss: 0.2746 - accuracy: 0.8916 - val_loss: 0.3519 - val_accuracy: 0.85402655 - accuracy: 0.93
# 2023-05-10 06:15:43.608 [101/model/501 (pid 32714)] Epoch 9/10
# 453/453 [==============================] - 0s 1ms/step - loss: 0.2592 - accuracy: 0.9015 - val_loss: 0.3552 - val_accuracy: 0.85841994 - accuracy: 0.93
# 2023-05-10 06:15:44.068 [101/model/501 (pid 32714)] Epoch 10/10
# 453/453 [==============================] - 0s 1ms/step - loss: 0.2536 - accuracy: 0.9067 - val_loss: 0.3691 - val_accuracy: 0.85042224 - accuracy: 0.93
# 2023-05-10 06:15:44.527 [101/model/501 (pid 32714)] (4529,)
# 2023-05-10 06:15:44.785 [101/model/501 (pid 32714)] Another shirt i really wanted to love. i adore green but so few tops are made in this color. (please make more!!) however, this shirt didn't work for me. i think it's a matter of where your curves live. the shirt was true to size, but my boobs meant i was showing more cleavage than the model, and the top part felt more like a bib than embroidery. sad coz it is lovely and feels lovely on. probably a great shirt for different body types. would love to see more green clothing....
# 2023-05-10 06:15:44.785 [101/model/501 (pid 32714)] (4529,)
# 2023-05-10 06:15:47.723 [101/model/501 (pid 32714)] Another shirt i really wanted to love. i adore green but so few tops are made in this color. (please make more!!) however, this shirt didn't work for me. i think it's a matter of where your curves live. the shirt was true to size, but my boobs meant i was showing more cleavage than the model, and the top part felt more like a bib than embroidery. sad coz it is lovely and feels lovely on. probably a great shirt for different body types. would love to see more green clothing....
# 2023-05-10 06:15:47.983 [101/model/501 (pid 32714)] Task finished successfully.
# 2023-05-10 06:15:48.389 [101/aggregate/502 (pid 575)] Task is starting.
# 2023-05-10 06:15:52.589 [101/aggregate/502 (pid 575)] ModelResult(name='Baseline', params='Always predict 1', pathspec='BaselineChallenge/101/baseline/500', acc=0.7584455729741665, rocauc=0.5)
# 2023-05-10 06:15:52.653 [101/aggregate/502 (pid 575)] ModelResult(name='NbowModel - vocab_sz: 100', params={'vocab_sz': 100}, pathspec='BaselineChallenge/101/model/501', acc=0.8140869949216163, rocauc=0.8399222702101444)
# 2023-05-10 06:15:52.654 [101/aggregate/502 (pid 575)] ModelResult(name='NbowModel - vocab_sz: 300', params={'vocab_sz': 300}, pathspec='BaselineChallenge/101/model/501', acc=0.8507396776330316, rocauc=0.8966707381003701)
# 2023-05-10 06:15:57.793 [101/aggregate/502 (pid 575)] ModelResult(name='NbowModel - vocab_sz: 500', params={'vocab_sz': 500}, pathspec='BaselineChallenge/101/model/501', acc=0.8582468536100685, rocauc=0.9043111959104712)
# 2023-05-10 06:15:58.069 [101/aggregate/502 (pid 575)] Task finished successfully.
# 2023-05-10 06:15:58.338 [101/end/503 (pid 677)] Task is starting.
# 2023-05-10 06:16:03.016 [101/end/503 (pid 677)] Task finished successfully.
# 2023-05-10 06:16:03.144 Done! See the run in the UI at https://ui-pw-673206860.outerbounds.dev/BaselineChallenge/101

# %%
from metaflow import Flow, Metaflow, Run, Step, Task

# list all flow runs
for flow in Metaflow():
    print(flow)
# Out:
# Flow('Template_Flow')
# Flow('TFlow1')
# Flow('RF_Flow')
# Flow('BSTFlow')
# Flow('NNFlow')
# Flow('BaselineNLPFlow')
# Flow('GoodFirstModelNLPFlow')
# Flow('Branch_Flow')
# Flow('TFlow2')
# Flow('TFlow3')
# Flow('TFlow4')
# Flow('TFlow5')
# Flow('BaselineChallenge')

# %%
# list all runs of a flow
for run in Flow('BaselineChallenge'):
    print(run)
# Out:
# Run('BaselineChallenge/97')
# Run('BaselineChallenge/96')
# Run('BaselineChallenge/95')
# Run('BaselineChallenge/94')
# Run('BaselineChallenge/93')
# Run('BaselineChallenge/92')
# Run('BaselineChallenge/91')
# Run('BaselineChallenge/90')
# Run('BaselineChallenge/89')
# Run('BaselineChallenge/88')
# Run('BaselineChallenge/87')
# Run('BaselineChallenge/86')
# Run('BaselineChallenge/85')
# Run('BaselineChallenge/84')
# Run('BaselineChallenge/83')
# Run('BaselineChallenge/82')
# Run('BaselineChallenge/81')
# Run('BaselineChallenge/80')
# Run('BaselineChallenge/79')
# Run('BaselineChallenge/78')
# Run('BaselineChallenge/77')
# Run('BaselineChallenge/76')
# Run('BaselineChallenge/75')
# Run('BaselineChallenge/74')
# Run('BaselineChallenge/73')
# Run('BaselineChallenge/72')
# Run('BaselineChallenge/71')
# Run('BaselineChallenge/70')
# Run('BaselineChallenge/69')
# Run('BaselineChallenge/68')
# Run('BaselineChallenge/67')
# Run('BaselineChallenge/66')
# Run('BaselineChallenge/65')
# Run('BaselineChallenge/64')
# Run('BaselineChallenge/63')
# Run('BaselineChallenge/62')
# Run('BaselineChallenge/61')
# Run('BaselineChallenge/60')
# Run('BaselineChallenge/59')
# Run('BaselineChallenge/58')
# Run('BaselineChallenge/57')
# Run('BaselineChallenge/56')
# Run('BaselineChallenge/55')
# Run('BaselineChallenge/54')
# Run('BaselineChallenge/53')
# Run('BaselineChallenge/52')
# Run('BaselineChallenge/51')
# Run('BaselineChallenge/50')
# Run('BaselineChallenge/49')
# Run('BaselineChallenge/48')
# Run('BaselineChallenge/47')
# Run('BaselineChallenge/46')
# Run('BaselineChallenge/45')

# %%
#latest run of a flow and check if its successful
latest_run = Flow('BaselineChallenge').latest_run
print(latest_run)
print(latest_run.successful)
# Out:
# Run('BaselineChallenge/97')
# True

# %%
#all steps in latest run
for step in Flow('BaselineChallenge').latest_run:
    print(step)
# Out:
# Step('BaselineChallenge/97/end')
# Step('BaselineChallenge/97/aggregate')
# Step('BaselineChallenge/97/model')
# Step('BaselineChallenge/97/baseline')
# Step('BaselineChallenge/97/start')

# %%
# list all task in a Step
for task in Step('BaselineChallenge/97/model'):
    print(task)
# Out:
# Task('BaselineChallenge/97/model/479')

# %%
for task in Step('BaselineChallenge/97/baseline'):
    print(task)
# Out:
# Task('BaselineChallenge/97/baseline/478')

# %%
# list all task in all step which failed
# TODO what is task specifically??
for step in Run('BaselineChallenge/45'):
    for task in step:
        if not task.successful:
            print("Task {} failed".format(task.pathspec))
            #print(task.stdout)
            #print(task.stderr)
# Out:
# Task BaselineChallenge/45/model/238 failed

# %%
# list all data artifacts in a Task
for dataArtifact in Task('BaselineChallenge/97/baseline/478'):
    print(dataArtifact)
# Out:
# DataArtifact('BaselineChallenge/97/baseline/478/result')
# DataArtifact('BaselineChallenge/97/baseline/478/result_serialized')
# DataArtifact('BaselineChallenge/97/baseline/478/df')
# DataArtifact('BaselineChallenge/97/baseline/478/traindf')
# DataArtifact('BaselineChallenge/97/baseline/478/valdf')
# DataArtifact('BaselineChallenge/97/baseline/478/data')
# DataArtifact('BaselineChallenge/97/baseline/478/kfold')
# DataArtifact('BaselineChallenge/97/baseline/478/name')
# DataArtifact('BaselineChallenge/97/baseline/478/scoring')
# DataArtifact('BaselineChallenge/97/baseline/478/split_size')

# %%
from metaflow import DataArtifact, Task
from model import ModelResult
'''
def classFromArgs(className, argDict):
    fieldSet = {f.name for f in fields(className) if f.init}
    filteredArgDict = {k : v for k, v in argDict.items() if k in fieldSet}
    return className(**filteredArgDict)
'''
#print(dir(Task('BaselineChallenge/97/model/479')['hyperparam_set']))
print(Task('BaselineChallenge/97/model/479')['hyperparam_set'].data)

print("________________________________________________________________")
data = Task('BaselineChallenge/97/baseline/478')['result'].data 
#print(data.keys())
#print(classFromArgs(ModelResult, data))
print(data)
# Out:
# [{'vocab_sz': 100}, {'vocab_sz': 300}, {'vocab_sz': 500}]
# ________________________________________________________________
# ModelResult(name='Baseline', params='Always predict 1', pathspec='BaselineChallenge/97/baseline/478', acc=0.7705895341134908, rocauc=0.5)

# %%
print((Task('BaselineChallenge/97/model/479')['results_serialized'].data))
print((Task('BaselineChallenge/97/baseline/478')['result_serialized'].data))
# Out:
# [{'name': 'NbowModel - vocab_sz: 100', 'params': {'vocab_sz': 100}, 'pathspec': 'BaselineChallenge/97/model/479', 'acc': 0.8180613822035769, 'rocauc': 0.8265107787684323}, {'name': 'NbowModel - vocab_sz: 300', 'params': {'vocab_sz': 300}, 'pathspec': 'BaselineChallenge/97/model/479', 'acc': 0.8567012585559726, 'rocauc': 0.8874310211218082}, {'name': 'NbowModel - vocab_sz: 500', 'params': {'vocab_sz': 500}, 'pathspec': 'BaselineChallenge/97/model/479', 'acc': 0.8507396776330316, 'rocauc': 0.888225536456423}]
# {'name': 'Baseline', 'params': 'Always predict 1', 'pathspec': 'BaselineChallenge/97/baseline/478', 'acc': 0.7705895341134908, 'rocauc': 0.5}
