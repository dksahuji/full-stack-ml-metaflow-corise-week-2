# %% [markdown]
# # Week 2 Project

# %% [markdown]
# Once again, we’ll be using the [Women's Ecommerce Clothing Reviews Dataset from Kaggle](https://www.kaggle.com/datasets/nicapotato/womens-ecommerce-clothing-reviews), which Kaggle states is a
#
# > dataset revolving around the reviews written by customers. Its nine supportive features offer a great environment to parse out the text through its multiple dimensions. Because this is real commercial data, it has been anonymized, and references to the company in the review text and body have been replaced with “retailer”.
#
# The machine learning task will be sentiment analysis, classifying each review as having positive or negative sentiment.

# %% [markdown]
# ## Task 1: Training and Evaluating Sentiment Analysis Models Using Metaflow
#
# In this task, you'll use Metaflow to build two machine learning models for sentiment analysis: a baseline *"majority class"* classifier and your own custom model. You'll then train both models in parallel and experiment with different hyperparameters to optimize their performance. Finally, you'll use this notebook and the Metaflow Client API to analyze the results of your different models and hyperparameters. Here's what you'll need to do:
#
# ### Step 1: Build the Workflows
# The first step in this task is to build the workflow(s) for sentiment analysis using the Metaflow framework. Start by creating a new flow in Metaflow and implementing the baseline *"majority class"* classifier. Then, build your own custom classifier using techniques you learned in Week 1, or any [helpful resources](https://outerbounds.com/docs/nlp-tutorial-L2/) you'd like. For your custom model, be sure to include steps for data preprocessing, model training, and evaluation.
#
# ### Step 2: Train Both Models in Parallel
# Once you've built your models, the next step is to train both models in parallel using the Metaflow framework. Use Metaflow to run both training jobs in parallel steps. If you get stuck, you may want to review the [FlowSpec branching documentation](https://docs.metaflow.org/metaflow/basics#branch).
#
# ### Step 3: Experiment with Hyperparameters
# After you've trained both models in parallel, the next step is to experiment with different hyperparameters to optimize their performance. Try different values for hyperparameters such as learning rate, batch size, and number of epochs, and record the results for each combination of hyperparameters as Data Artifacts in Metaflow.
#
# ### Step 4: Analyze the Results
# Finally, use this notebook and the Metaflow Client API to analyze the results of your different models and hyperparameters. Create visualizations to compare the performance of the two models and identify the best hyperparameters for each one.
#
# By completing this task, you'll gain experience working with the Metaflow framework and learn how to build and optimize machine learning workflows for sentiment analysis.

# %%
from collections import Counter
import pandas as pd
import numpy as np 
from termcolor import colored
import matplotlib.pyplot as plt
import seaborn as sns
import string

# You can style your plots here, but it is not part of the project.
YELLOW = '#FFBC00'
GREEN = '#37795D'
PURPLE = '#5460C0'
BACKGROUND = '#F4EBE6'
colors = [GREEN, PURPLE]
custom_params = {
    'axes.spines.right': False, 'axes.spines.top': False,
    'axes.facecolor':BACKGROUND, 'figure.facecolor': BACKGROUND, 
    'figure.figsize':(8, 8)
}
sns_palette = sns.color_palette(colors, len(colors))
sns.set_theme(style='ticks', rc=custom_params)

# %%
import io
from sklearn.model_selection import train_test_split

# TODO: load the data. 
df = pd.read_csv("../data/Womens Clothing E-Commerce Reviews.csv")
labeling_function = lambda row: 1 if row['rating']>=4 else 0
# transformations
df.columns = ["_".join(name.lower().strip().split()) for name in df.columns]
df = df[~df.review_text.isna()]
df['review'] = df['review_text'].astype('str')
_has_review_df = df[df['review_text'] != 'nan']
reviews = _has_review_df['review_text']
labels = _has_review_df.apply(labeling_function, axis=1)
df = pd.DataFrame({'label': labels, **_has_review_df})

# split into training and validation.
_df = pd.DataFrame({'review': reviews, 'label': labels})
traindf, valdf = train_test_split(_df, test_size=0.2)

# %%
# TODO: build the majority class baseline model. 
# TODO: find the majority class in the labels. 🤔
# TODO: score the model on valdf with a 2D metric space: sklearn.metrics.accuracy_score, sklearn.metrics.roc_auc_score
    # Documentation on suggested model-scoring approach: https://scikit-learn.org/stable/modules/model_evaluation.html

import numpy as np
from sklearn.dummy import DummyClassifier
from sklearn.metrics import accuracy_score, roc_auc_score, confusion_matrix
np.random.seed(42)

dummy_clf = DummyClassifier(strategy="most_frequent")
dummy_clf.fit(traindf['review'], traindf['label'])

preds = dummy_clf.predict(valdf['review'])

base_acc = accuracy_score(valdf['label'], preds)
base_rocauc = roc_auc_score(valdf['label'], preds)

print("accuracy: " , base_acc)
print("ROC AUC: ", base_rocauc)
# Out:
# accuracy:  0.7688231397659527
# ROC AUC:  0.5

# %%
# %%writefile model.py
# TODO: modify this custom model to your liking. Check out this tutorial for more on this class: https://outerbounds.com/docs/nlp-tutorial-L2/
# TODO: train the model on traindf.
# TODO: score the model on valdf with _the same_ 2D metric space you used in previous cell.
# TODO: test your model works by importing the model module in notebook cells, and trying to fit traindf and score predictions on the valdf data!

import tensorflow as tf
from tensorflow.keras import layers, optimizers, regularizers
from sklearn.base import BaseEstimator, ClassifierMixin
from sklearn.metrics import accuracy_score, roc_auc_score
from sklearn.feature_extraction.text import CountVectorizer

class NbowModel():
    def __init__(self, vocab_sz):

        self.vocab_sz = vocab_sz

        # Instantiate the CountVectorizer
        self.cv = CountVectorizer(
            min_df=.005, max_df = .75, stop_words='english', 
            strip_accents='ascii', max_features=self.vocab_sz
        )

        # Define the keras model
        inputs = tf.keras.Input(shape=(self.vocab_sz,), 
                                name='input')
        x = layers.Dropout(0.10)(inputs)
        x = layers.Dense(
            15, activation="relu",
            kernel_regularizer=regularizers.L1L2(l1=1e-5, l2=1e-4)
        )(x)
        predictions = layers.Dense(1, activation="sigmoid",)(x)
        self.model = tf.keras.Model(inputs, predictions)
        opt = optimizers.Adam(learning_rate=0.002)
        self.model.compile(loss="binary_crossentropy", 
                           optimizer=opt, metrics=["accuracy"])

    def fit(self, X, y):
        print(X.shape)
        print(X[0])
        res = self.cv.fit_transform(X).toarray()
        self.model.fit(x=res, y=y, batch_size=32, 
                       epochs=10, validation_split=.2)
    
    def predict(self, X):
        print(X.shape)
        print(X[0])
        res = self.cv.transform(X).toarray()
        return self.model.predict(res)
    
    def eval_acc(self, X, labels, threshold=.5):
        return accuracy_score(labels, 
                              self.predict(X) > threshold)
    
    def eval_rocauc(self, X, labels):
        return roc_auc_score(labels,  self.predict(X))

    @property
    def model_dict(self): 
        return {'vectorizer':self.cv, 'model': self.model}

    @classmethod
    def from_dict(cls, model_dict):
        "Get Model from dictionary"
        nbow_model = cls(len(
            model_dict['vectorizer'].vocabulary_
        ))
        nbow_model.model = model_dict['model']
        nbow_model.cv = model_dict['vectorizer']
        return nbow_model
# Out:
# Overwriting model.py

# %%
# %%writefile baseline_challenge.py
# TODO: In this cell, write your BaselineChallenge flow in the baseline_challenge.py file.

from metaflow import FlowSpec, step, Flow, current, Parameter, IncludeFile, card, current
from metaflow.cards import Table, Markdown, Artifact, Image
import numpy as np 
from dataclasses import dataclass, asdict

labeling_function = lambda row: 1 if row['rating']>=4 else 0

@dataclass
class ModelResult:
    "A custom struct for storing model evaluation results."
    name: None
    params: None
    pathspec: None
    acc: None
    rocauc: None

class BaselineChallenge(FlowSpec):

    split_size = Parameter('split-sz', default=0.2)
    data = IncludeFile('data', default='../data/Womens Clothing E-Commerce Reviews.csv')
    kfold = Parameter('k', default=5)
    scoring = Parameter('scoring', default='accuracy')

    @step
    def start(self):

        import pandas as pd
        import io 
        from sklearn.model_selection import train_test_split
        
        # load dataset packaged with the flow.
        # this technique is convenient when working with small datasets that need to move to remove tasks.
        df = pd.read_csv(io.StringIO(self.data), index_col = 0)
        # TODO: load the data. 
        # Look up a few lines to the IncludeFile('data', default='Womens Clothing E-Commerce Reviews.csv'). 
        # You can find documentation on IncludeFile here: https://docs.metaflow.org/scaling/data#data-in-local-files

        # filter down to reviews and labels 
        df.columns = ["_".join(name.lower().strip().split()) for name in df.columns]
        df = df[~df.review_text.isna()]
        df['review'] = df['review_text'].astype('str')
        _has_review_df = df[df['review_text'] != 'nan']
        reviews = _has_review_df['review_text']
        labels = _has_review_df.apply(labeling_function, axis=1)
        self.df = pd.DataFrame({'label': labels, **_has_review_df})

        # split the data 80/20, or by using the flow's split-sz CLI argument
        _df = pd.DataFrame({'review': reviews, 'label': labels})
        self.traindf, self.valdf = train_test_split(_df, test_size=self.split_size)
        print(f'num of rows in train set: {self.traindf.shape[0]}')
        print(f'num of rows in validation set: {self.valdf.shape[0]}')

        self.next(self.baseline, self.model)

    @step
    def baseline(self):
        "Compute the baseline"

        from sklearn.metrics import accuracy_score, roc_auc_score
        self._name = "baseline"
        params = "Always predict 1"
        pathspec = f"{current.flow_name}/{current.run_id}/{current.step_name}/{current.task_id}"

        import numpy as np
        from sklearn.dummy import DummyClassifier
        from sklearn.metrics import accuracy_score, roc_auc_score, confusion_matrix
        np.random.seed(42)
        
        dummy_clf = DummyClassifier(strategy="most_frequent")
        dummy_clf.fit(self.traindf['review'], self.traindf['label'])
        
        predictions = dummy_clf.predict(self.valdf['review'])

        acc = accuracy_score(self.valdf['label'], predictions)
        rocauc = roc_auc_score(self.valdf['label'], predictions)
 
        self.result = ModelResult("Baseline", params, pathspec, acc, rocauc)
        self.result_serialized = asdict(ModelResult("Baseline", params, pathspec, acc, rocauc))
        
        self.next(self.aggregate)

    @step
    def model(self):

        # TODO: import your model if it is defined in another file.
        from model import NbowModel

        self._name = "model"
        # NOTE: If you followed the link above to find a custom model implementation, 
            # you will have noticed your model's vocab_sz hyperparameter.
            # Too big of vocab_sz causes an error. Can you explain why? 
        self.hyperparam_set = [{'vocab_sz': 100}, {'vocab_sz': 300}, {'vocab_sz': 500}]  
        pathspec = f"{current.flow_name}/{current.run_id}/{current.step_name}/{current.task_id}"

        self.results = []
        self.results_serialized = []
        for params in self.hyperparam_set:
            model = NbowModel(**params) 
            model.fit(X=self.traindf['review'].values, y=self.traindf['label'])
            acc = model.eval_acc(X=self.valdf['review'].values, labels=self.valdf['label']) 
            rocauc = model.eval_rocauc(X=self.valdf['review'].values, labels=self.valdf['label'])
            self.results.append(ModelResult(f"NbowModel - vocab_sz: {params['vocab_sz']}", params, pathspec, acc, rocauc))
            self.results_serialized.append(asdict(ModelResult(f"NbowModel - vocab_sz: {params['vocab_sz']}", params, pathspec, acc, rocauc)))
        self.next(self.aggregate)

    @step
    def aggregate(self, inputs):
        pass
        self.next(self.end)

    @step
    def end(self):
        pass

if __name__ == '__main__':
    BaselineChallenge()
# Out:
# Overwriting baseline_challenge.py

# %%
! python baseline_challenge.py run --data /home/workspace/workspaces/full-stack-ml-metaflow-corise-week-2/data/Womens\ Clothing\ E-Commerce\ Reviews.csv
# Out:
# Metaflow 2.8.3.1+ob(v1) executing BaselineChallenge for user:sandbox
# Validating your flow...
#     The graph looks good!
# Running pylint...
#     Pylint is happy!
# Including file /home/workspace/workspaces/full-stack-ml-metaflow-corise-week-2/data/Womens Clothing E-Commerce Reviews.csv of size 8MB
# 2023-05-09 10:29:09.484 Workflow starting (run-id 93), see it in the UI at https://ui-pw-673206860.outerbounds.dev/BaselineChallenge/93
# 2023-05-09 10:29:09.707 [93/start/456 (pid 25847)] Task is starting.
# 2023-05-09 10:29:12.678 [93/start/456 (pid 25847)] num of rows in train set: 18112
# 2023-05-09 10:29:15.286 [93/start/456 (pid 25847)] num of rows in validation set: 4529
# 2023-05-09 10:29:15.483 [93/start/456 (pid 25847)] Task finished successfully.
# 2023-05-09 10:29:15.797 [93/baseline/457 (pid 25950)] Task is starting.
# 2023-05-09 10:29:15.949 [93/model/458 (pid 25953)] Task is starting.
# 2023-05-09 10:29:20.192 [93/model/458 (pid 25953)] 2023-05-09 10:29:20.192080: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 AVX512F FMA
# 2023-05-09 10:29:20.304 [93/model/458 (pid 25953)] (18112,)
# 2023-05-09 10:29:20.997 [93/model/458 (pid 25953)] To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-05-09 10:29:20.998 [93/model/458 (pid 25953)] 2023-05-09 10:29:20.997722: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:116] None of the MLIR optimization passes are enabled (registered 2)
# 2023-05-09 10:29:21.017 [93/model/458 (pid 25953)] 2023-05-09 10:29:21.017874: I tensorflow/core/platform/profile_utils/cpu_utils.cc:112] CPU Frequency: 2500000000 Hz
# 2023-05-09 10:29:21.027 [93/model/458 (pid 25953)] I saw this top online and read the reviews so i passed when i went into the store. when i went in again i thought i would give it a try. so glad i did ! it fits great and is way way prettier in person ! i ended up buying it and so glad i did !
# 2023-05-09 10:29:21.027 [93/model/458 (pid 25953)] Epoch 1/10
# 2023-05-09 10:29:21.328 [93/baseline/457 (pid 25950)] Task finished successfully.
# 453/453 [==============================] - 1s 2ms/step - loss: 0.5056 - accuracy: 0.7795 - val_loss: 0.4143 - val_accuracy: 0.8131.6310 - accuracy: 0.78
# 2023-05-09 10:29:22.183 [93/model/458 (pid 25953)] Epoch 2/10
# 453/453 [==============================] - 0s 810us/step - loss: 0.4303 - accuracy: 0.8060 - val_loss: 0.4135 - val_accuracy: 0.81182 - accuracy: 0.81
# 2023-05-09 10:29:22.551 [93/model/458 (pid 25953)] Epoch 3/10
# 453/453 [==============================] - 0s 791us/step - loss: 0.4135 - accuracy: 0.8145 - val_loss: 0.4120 - val_accuracy: 0.81290 - accuracy: 0.78
# 2023-05-09 10:29:22.911 [93/model/458 (pid 25953)] Epoch 4/10
# 453/453 [==============================] - 0s 803us/step - loss: 0.4174 - accuracy: 0.8138 - val_loss: 0.4106 - val_accuracy: 0.81313 - accuracy: 0.81
# 2023-05-09 10:29:23.275 [93/model/458 (pid 25953)] Epoch 5/10
epoch 4/10
# 453/453 [==============================] - 0s 1ms/step - loss: 0.3096 - accuracy: 0.8689 - val_loss: 0.3414 - val_accuracy: 0.8534410 - accuracy: 0.87
# 2023-05-09 10:29:34.634 [93/model/458 (pid 25953)] Epoch 5/10
# 453/453 [==============================] - 0s 1ms/step - loss: 0.2988 - accuracy: 0.8821 - val_loss: 0.3403 - val_accuracy: 0.8534067 - accuracy: 0.87
# 2023-05-09 10:29:35.095 [93/model/458 (pid 25953)] Epoch 6/10
# 453/453 [==============================] - 0s 992us/step - loss: 0.2876 - accuracy: 0.8872 - val_loss: 0.3468 - val_accuracy: 0.85407 - accuracy: 0.93
# 2023-05-09 10:29:35.545 [93/model/458 (pid 25953)] Epoch 7/10
# 453/453 [==============================] - 0s 1ms/step - loss: 0.2778 - accuracy: 0.8877 - val_loss: 0.3511 - val_accuracy: 0.8540210 - accuracy: 0.96
# 2023-05-09 10:29:36.000 [93/model/458 (pid 25953)] Epoch 8/10
# 453/453 [==============================] - 0s 1ms/step - loss: 0.2742 - accuracy: 0.8939 - val_loss: 0.3584 - val_accuracy: 0.8526758 - accuracy: 0.93
# 2023-05-09 10:29:36.458 [93/model/458 (pid 25953)] Epoch 9/10
# 453/453 [==============================] - 0s 1ms/step - loss: 0.2688 - accuracy: 0.8966 - val_loss: 0.3602 - val_accuracy: 0.8518276 - accuracy: 0.90
# 2023-05-09 10:29:36.918 [93/model/458 (pid 25953)] Epoch 10/10
# 453/453 [==============================] - 0s 1ms/step - loss: 0.2537 - accuracy: 0.9002 - val_loss: 0.3663 - val_accuracy: 0.8532490 - accuracy: 0.96
# 2023-05-09 10:29:37.390 [93/model/458 (pid 25953)] (4529,)
# 2023-05-09 10:29:37.665 [93/model/458 (pid 25953)] I was so excited to receive this topped then i tried it on. i am a petite and i normally wear an xs so i ordered it in both a size 0 and a size 2. it was huge! it looked like i was wearing a potato sack!!! i really wanted it to work because the fabric is absolutely beautiful! i am so disappointed.
# 2023-05-09 10:29:37.665 [93/model/458 (pid 25953)] (4529,)
# 2023-05-09 10:29:40.584 [93/model/458 (pid 25953)] I was so excited to receive this topped then i tried it on. i am a petite and i normally wear an xs so i ordered it in both a size 0 and a size 2. it was huge! it looked like i was wearing a potato sack!!! i really wanted it to work because the fabric is absolutely beautiful! i am so disappointed.
# 2023-05-09 10:29:40.823 [93/model/458 (pid 25953)] Task finished successfully.
# 2023-05-09 10:29:41.233 [93/aggregate/459 (pid 26289)] Task is starting.
# 2023-05-09 10:29:43.993 [93/aggregate/459 (pid 26289)] Task finished successfully.
# 2023-05-09 10:29:44.297 [93/end/460 (pid 26346)] Task is starting.
# 2023-05-09 10:29:46.576 [93/end/460 (pid 26346)] Task finished successfully.
# 2023-05-09 10:29:46.719 Done! See the run in the UI at https://ui-pw-673206860.outerbounds.dev/BaselineChallenge/93

# %% [markdown]
# ## Task 2: Anticipating Failure in Your Machine Learning Project
#
# In this task, you'll practice anticipating potential failure modes in a sentiment analysis classifier and develop strategies to mitigate them. Here's what you'll need to do:
# ### Step 1: Identify Potential Failure Modes
#
# The first step in anticipating failure in your machine learning project is to identify potential failure modes. Start by brainstorming ways in which your project could fail from an engineering point of view. For example, your model could overfit to the training data or suffer from data bias.
#
# ##### significant change class skew in daily data
# ##### data bias
# ##### discrimination like gender bias, socio-economic bias, racial bias etc
# ##### label error
# ##### sensitivity to data noise
# ##### sensitivity to label noise
# ##### underfitting / over fitting
# ##### sudden large change in driving metrics
# ##### choice of metrics
# #####
#
#
# ### Step 2: Develop Strategies to Mitigate Failure Modes
#
# Once you've identified potential failure modes, the next step is to develop strategies to mitigate them. Think about what measures you could take to fix the issue if it were to occur. For example, if your model is overfitting to the training data, you could try regularization techniques such as L1 or L2 regularization to reduce the complexity of the model.
#
#
# ##### check class skew in daily data
# ##### check data bias : check population bias because of nature of data presentation/collection (like 1st slot getting very high clicks independent of content). Fix it if possible, using methods like Inverse Propensity Weighing (IPW), Doubly Robust (DR) estimators etc on loss like click prediction loss and rate features like CTR.
# ##### check discrimination : check for gender bias, socio-economic bias, racial bias etc
# ##### find label error using label correction libraries
# ##### model sensitivity to data noise: data augmentation
# ##### analysis on model sensitivity to label noise
# ##### check underfitting / over fitting: increase model complexity / add regularisation
# ##### if learning not happening use batch norm and stuff for improve loss surface or gradient magnitude / co-variate shift
# ##### gaurd rails (sudden large change in metrics): have alerts for metrics moving out of gaurd rails
# ##### run offline test to validate improvement (if possible do counterfactual evaluation to measure improvement)
#
#
# ### Step 3: Plan Ahead to Avoid Failure Modes
#
# Finally, it's important to plan ahead to avoid potential failure modes in the first place. Think about what you could have done initially to avoid these failure modes. For example, you could have collected a diverse set of training data to reduce data bias or experimented with different model architectures to find the best solution for your problem.
#
# The key to anticipating failure in your machine learning project is to be proactive rather than reactive. By identifying potential failure modes ahead of time and developing strategies to mitigate them, you'll be better equipped to build a successful machine learning project.

# %% [markdown]
# ## Task 3: Visualizing ML Results with MF Cards
# Now it is time to iterate. Extend the flow in your `baseline_challenge.py` file to include a step that aggregates all of the results from hyperparameter tuning jobs, and logs results and a data visualiation in a Metaflow card.

# %%
# %%writefile baseline_challenge_1.py
# TODO: In this cell, write your BaselineChallenge flow in the baseline_challenge.py file.

from metaflow import FlowSpec, step, Flow, current, Parameter, IncludeFile, card, current
from metaflow.cards import Table, Markdown, Artifact, Image
import numpy as np 
from dataclasses import dataclass, asdict


labeling_function = lambda row: 1 if row['rating']>=4 else 0

@dataclass
class ModelResult:
    "A custom struct for storing model evaluation results."
    name: None
    params: None
    pathspec: None
    acc: None
    rocauc: None

class BaselineChallenge(FlowSpec):

    split_size = Parameter('split-sz', default=0.2)
    data = IncludeFile('data', default='Womens Clothing E-Commerce Reviews.csv')
    kfold = Parameter('k', default=5)
    scoring = Parameter('scoring', default='accuracy')
    @step
    def start(self):

        import pandas as pd
        import io 
        from sklearn.model_selection import train_test_split
        
        # load dataset packaged with the flow.
        # this technique is convenient when working with small datasets that need to move to remove tasks.
        df = pd.read_csv(io.StringIO(self.data), index_col = 0)
        # TODO: load the data. 
        # Look up a few lines to the IncludeFile('data', default='Womens Clothing E-Commerce Reviews.csv'). 
        # You can find documentation on IncludeFile here: https://docs.metaflow.org/scaling/data#data-in-local-files

        # filter down to reviews and labels 
        df.columns = ["_".join(name.lower().strip().split()) for name in df.columns]
        df = df[~df.review_text.isna()]
        df['review'] = df['review_text'].astype('str')
        _has_review_df = df[df['review_text'] != 'nan']
        reviews = _has_review_df['review_text']
        labels = _has_review_df.apply(labeling_function, axis=1)
        self.df = pd.DataFrame({'label': labels, **_has_review_df})

        # split the data 80/20, or by using the flow's split-sz CLI argument
        _df = pd.DataFrame({'review': reviews, 'label': labels})
        self.traindf, self.valdf = train_test_split(_df, test_size=self.split_size)
        print(f'num of rows in train set: {self.traindf.shape[0]}')
        print(f'num of rows in validation set: {self.valdf.shape[0]}')

        self.next(self.baseline, self.model)

    @step
    def baseline(self):
        "Compute the baseline"

        self._name = "baseline"
        params = "Always predict 1"
        pathspec = f"{current.flow_name}/{current.run_id}/{current.step_name}/{current.task_id}"

        import numpy as np
        from sklearn.dummy import DummyClassifier
        from sklearn.metrics import accuracy_score, roc_auc_score, confusion_matrix
        np.random.seed(42)
        
        dummy_clf = DummyClassifier(strategy="most_frequent")
        dummy_clf.fit(self.traindf['review'], self.traindf['label'])
        
        predictions = dummy_clf.predict(self.valdf['review'])

        acc = accuracy_score(self.valdf['label'], predictions)
        rocauc = roc_auc_score(self.valdf['label'], predictions)
 
        self.result = ModelResult("Baseline", params, pathspec, acc, rocauc)
        self.result_serialized = asdict(ModelResult("Baseline", params, pathspec, acc, rocauc))
        self.next(self.aggregate)

    @step
    def model(self):

        # TODO: import your model if it is defined in another file.
        from model import NbowModel

        self._name = "model"
        # NOTE: If you followed the link above to find a custom model implementation, 
            # you will have noticed your model's vocab_sz hyperparameter.
            # Too big of vocab_sz causes an error. Can you explain why? 
        self.hyperparam_set = [{'vocab_sz': 100}, {'vocab_sz': 300}, {'vocab_sz': 500}]  
        pathspec = f"{current.flow_name}/{current.run_id}/{current.step_name}/{current.task_id}"

        self.results = []
        self.results_serialized = []
        for params in self.hyperparam_set:
            model = NbowModel(**params) 
            model.fit(X=self.traindf['review'].values, y=self.traindf['label'])
            acc = model.eval_acc(X=self.valdf['review'].values, labels=self.valdf['label']) 
            rocauc = model.eval_rocauc(X=self.valdf['review'].values, labels=self.valdf['label'])
            self.results.append(ModelResult(f"NbowModel - vocab_sz: {params['vocab_sz']}", params, pathspec, acc, rocauc))
            self.results_serialized.append(asdict(ModelResult(f"NbowModel - vocab_sz: {params['vocab_sz']}", params, pathspec, acc, rocauc)))
        self.next(self.aggregate)

    def add_one(self, rows, result, df):
        "A helper function to load results."
        rows.append([
            Markdown(result.name),
            Artifact(result.params),
            Artifact(result.pathspec),
            Artifact(result.acc),
            Artifact(result.rocauc)
        ])
        df['name'].append(result.name)
        df['accuracy'].append(result.acc)
        return rows, df

    @card(type="corise") # TODO: Set your card type to "corise". 
            # I wonder what other card types there are?
            # https://docs.metaflow.org/metaflow/visualizing-results
            # https://github.com/outerbounds/metaflow-card-altair/blob/main/altairflow.py
    @step
    def aggregate(self, inputs):

        import seaborn as sns
        import matplotlib.pyplot as plt
        from matplotlib import rcParams 
        rcParams.update({'figure.autolayout': True})

        rows = []
        violin_plot_df = {'name': [], 'accuracy': []}
        for task in inputs:
            if task._name == "model": 
                for result in task.results:
                    print(result)
                    rows, violin_plot_df = self.add_one(rows, result, violin_plot_df)
            elif task._name == "baseline":
                print(task.result)
                rows, violin_plot_df = self.add_one(rows, task.result, violin_plot_df)
            else:
                raise ValueError("Unknown task._name type. Cannot parse results.")
            
        current.card.append(Markdown("# All models from this flow run"))

        # TODO: Add a Table of the results to your card! 
        current.card.append(
            Table(
                rows, # TODO: What goes here to populate the Table in the card? 
                headers=["Model name", "Params", "Task pathspec", "Accuracy", "ROCAUC"]
            )
        )
        
        fig, ax = plt.subplots(1,1)
        plt.xticks(rotation=40)
        sns.violinplot(data=violin_plot_df, x="name", y="accuracy", ax=ax)
        
        # TODO: Append the matplotlib fig to the card
        # Docs: https://docs.metaflow.org/metaflow/visualizing-results/easy-custom-reports-with-card-components#showing-plots
        current.card.append(Image.from_matplotlib(fig))
        self.merge_artifacts(inputs, include=['result_serialized', 'results_serialized'])
        self.next(self.end)

    @step
    def end(self):
        pass

if __name__ == '__main__':
    BaselineChallenge()
# Out:
# Overwriting baseline_challenge_1.py

# %%
! python baseline_challenge_1.py run --data /home/workspace/workspaces/full-stack-ml-metaflow-corise-week-2/data/Womens\ Clothing\ E-Commerce\ Reviews.csv
# Out:
# Metaflow 2.8.3.1+ob(v1) executing BaselineChallenge for user:sandbox
# Validating your flow...
#     The graph looks good!
# Running pylint...
#     Pylint is happy!
# Including file /home/workspace/workspaces/full-stack-ml-metaflow-corise-week-2/data/Womens Clothing E-Commerce Reviews.csv of size 8MB
# 2023-05-09 10:38:41.258 Workflow starting (run-id 97), see it in the UI at https://ui-pw-673206860.outerbounds.dev/BaselineChallenge/97
# 2023-05-09 10:38:41.468 [97/start/477 (pid 28030)] Task is starting.
# 2023-05-09 10:38:44.421 [97/start/477 (pid 28030)] num of rows in train set: 18112
# 2023-05-09 10:38:47.039 [97/start/477 (pid 28030)] num of rows in validation set: 4529
# 2023-05-09 10:38:47.352 [97/start/477 (pid 28030)] Task finished successfully.
# 2023-05-09 10:38:47.733 [97/baseline/478 (pid 28136)] Task is starting.
# 2023-05-09 10:38:47.896 [97/model/479 (pid 28139)] Task is starting.
# 2023-05-09 10:38:52.185 [97/model/479 (pid 28139)] 2023-05-09 10:38:52.185481: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 AVX512F FMA
# 2023-05-09 10:38:52.318 [97/model/479 (pid 28139)] (18112,)
# 2023-05-09 10:38:53.008 [97/model/479 (pid 28139)] To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-05-09 10:38:53.009 [97/model/479 (pid 28139)] 2023-05-09 10:38:53.008800: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:116] None of the MLIR optimization passes are enabled (registered 2)
# 2023-05-09 10:38:53.009 [97/model/479 (pid 28139)] 2023-05-09 10:38:53.009186: I tensorflow/core/platform/profile_utils/cpu_utils.cc:112] CPU Frequency: 2500000000 Hz
# 2023-05-09 10:38:53.019 [97/model/479 (pid 28139)] I like this top a lot - it's cuter in person than it looks on the model -- it's a little heathered. it definitely fits slimmer one me than on the model, and i'm pretty small on top.
# 2023-05-09 10:38:53.020 [97/model/479 (pid 28139)]
# 2023-05-09 10:38:53.020 [97/model/479 (pid 28139)] overall, nice to see a reasonably priced basic t on the retailer site
# 2023-05-09 10:38:53.020 [97/model/479 (pid 28139)] Epoch 1/10
# 2023-05-09 10:38:53.483 [97/baseline/478 (pid 28136)] Task finished successfully.
# 453/453 [==============================] - 1s 2ms/step - loss: 0.4962 - accuracy: 0.7780 - val_loss: 0.4197 - val_accuracy: 0.8084.6389 - accuracy: 0.68
# 2023-05-09 10:38:54.188 [97/model/479 (pid 28139)] Epoch 2/10
# 453/453 [==============================] - 0s 806us/step - loss: 0.4212 - accuracy: 0.8109 - val_loss: 0.4190 - val_accuracy: 0.80684 - accuracy: 0.81
# 2023-05-09 10:38:54.554 [97/model/479 (pid 28139)] Epoch 3/10
# 453/453 [==============================] - 0s 852us/step - loss: 0.4119 - accuracy: 0.8176 - val_loss: 0.4159 - val_accuracy: 0.80769 - accuracy: 0.75
# 2023-05-09 10:38:54.941 [97/model/479 (pid 28139)] Epoch 4/10
# 453/453 [==============================] - 0s 803us/step - loss: 0.4073 - accuracy: 0.8195 - val_loss: 0.4124 - val_accuracy: 0.81295 - accuracy: 0.68
] Epoch 2/10
# 453/453 [==============================] - 0s 1ms/step - loss: 0.3217 - accuracy: 0.8667 - val_loss: 0.3437 - val_accuracy: 0.8518589 - accuracy: 0.90
# 2023-05-09 10:39:05.796 [97/model/479 (pid 28139)] Epoch 3/10
# 453/453 [==============================] - 0s 1ms/step - loss: 0.3066 - accuracy: 0.8715 - val_loss: 0.3418 - val_accuracy: 0.8559559 - accuracy: 0.84
# 2023-05-09 10:39:06.258 [97/model/479 (pid 28139)] Epoch 4/10
# 453/453 [==============================] - 0s 1ms/step - loss: 0.3017 - accuracy: 0.8764 - val_loss: 0.3413 - val_accuracy: 0.8540197 - accuracy: 0.84
# 2023-05-09 10:39:06.718 [97/model/479 (pid 28139)] Epoch 5/10
# 453/453 [==============================] - 0s 1ms/step - loss: 0.2862 - accuracy: 0.8859 - val_loss: 0.3400 - val_accuracy: 0.8521760 - accuracy: 0.96
# 2023-05-09 10:39:07.173 [97/model/479 (pid 28139)] Epoch 6/10
# 453/453 [==============================] - 0s 993us/step - loss: 0.2834 - accuracy: 0.8866 - val_loss: 0.3505 - val_accuracy: 0.84825 - accuracy: 0.87
# 2023-05-09 10:39:07.624 [97/model/479 (pid 28139)] Epoch 7/10
# 453/453 [==============================] - 0s 1ms/step - loss: 0.2792 - accuracy: 0.8908 - val_loss: 0.3531 - val_accuracy: 0.8504930 - accuracy: 0.90
# 2023-05-09 10:39:08.081 [97/model/479 (pid 28139)] Epoch 8/10
# 453/453 [==============================] - 0s 1ms/step - loss: 0.2643 - accuracy: 0.8979 - val_loss: 0.3560 - val_accuracy: 0.8518655 - accuracy: 0.96
# 2023-05-09 10:39:08.553 [97/model/479 (pid 28139)] Epoch 9/10
# 453/453 [==============================] - 0s 1ms/step - loss: 0.2612 - accuracy: 0.8997 - val_loss: 0.3633 - val_accuracy: 0.8493844 - accuracy: 0.87
# 2023-05-09 10:39:09.050 [97/model/479 (pid 28139)] Epoch 10/10
# 453/453 [==============================] - 0s 1ms/step - loss: 0.2497 - accuracy: 0.9051 - val_loss: 0.3622 - val_accuracy: 0.8493408 - accuracy: 0.93
# 2023-05-09 10:39:09.516 [97/model/479 (pid 28139)] (4529,)
# 2023-05-09 10:39:09.772 [97/model/479 (pid 28139)] I saw this online and loved it, then when it was on sale i went into the store and tried it on and i couldn't resist. the only size that was left in stores was an xs petit and i didn't think that it would fit me because i am usually a regular s/m but it was super comfortable and very stylish. it wasn't too big or too small, it fit me just right without any awkwardness.
# 2023-05-09 10:39:09.772 [97/model/479 (pid 28139)] (4529,)
# 2023-05-09 10:39:12.786 [97/model/479 (pid 28139)] I saw this online and loved it, then when it was on sale i went into the store and tried it on and i couldn't resist. the only size that was left in stores was an xs petit and i didn't think that it would fit me because i am usually a regular s/m but it was super comfortable and very stylish. it wasn't too big or too small, it fit me just right without any awkwardness.
# 2023-05-09 10:39:13.024 [97/model/479 (pid 28139)] Task finished successfully.
# 2023-05-09 10:39:13.348 [97/aggregate/480 (pid 28472)] Task is starting.
# 2023-05-09 10:39:16.429 [97/aggregate/480 (pid 28472)] ModelResult(name='Baseline', params='Always predict 1', pathspec='BaselineChallenge/97/baseline/478', acc=0.7705895341134908, rocauc=0.5)
# 2023-05-09 10:39:16.475 [97/aggregate/480 (pid 28472)] ModelResult(name='NbowModel - vocab_sz: 100', params={'vocab_sz': 100}, pathspec='BaselineChallenge/97/model/479', acc=0.8180613822035769, rocauc=0.8265107787684323)
# 2023-05-09 10:39:16.475 [97/aggregate/480 (pid 28472)] ModelResult(name='NbowModel - vocab_sz: 300', params={'vocab_sz': 300}, pathspec='BaselineChallenge/97/model/479', acc=0.8567012585559726, rocauc=0.8874310211218082)
# 2023-05-09 10:39:19.165 [97/aggregate/480 (pid 28472)] ModelResult(name='NbowModel - vocab_sz: 500', params={'vocab_sz': 500}, pathspec='BaselineChallenge/97/model/479', acc=0.8507396776330316, rocauc=0.888225536456423)
# 2023-05-09 10:39:19.386 [97/aggregate/480 (pid 28472)] Task finished successfully.
# 2023-05-09 10:39:19.710 [97/end/481 (pid 28571)] Task is starting.
# 2023-05-09 10:39:22.015 [97/end/481 (pid 28571)] Task finished successfully.
# 2023-05-09 10:39:22.129 Done! See the run in the UI at https://ui-pw-673206860.outerbounds.dev/BaselineChallenge/97

# %%
from metaflow import Flow, Metaflow, Run, Step, Task

# list all flow runs
for flow in Metaflow():
    print(flow)
# Out:
# Flow('Template_Flow')
# Flow('TFlow1')
# Flow('RF_Flow')
# Flow('BSTFlow')
# Flow('NNFlow')
# Flow('BaselineNLPFlow')
# Flow('GoodFirstModelNLPFlow')
# Flow('Branch_Flow')
# Flow('TFlow2')
# Flow('TFlow3')
# Flow('TFlow4')
# Flow('TFlow5')
# Flow('BaselineChallenge')

# %%
# list all runs of a flow
for run in Flow('BaselineChallenge'):
    print(run)
# Out:
# Run('BaselineChallenge/97')
# Run('BaselineChallenge/96')
# Run('BaselineChallenge/95')
# Run('BaselineChallenge/94')
# Run('BaselineChallenge/93')
# Run('BaselineChallenge/92')
# Run('BaselineChallenge/91')
# Run('BaselineChallenge/90')
# Run('BaselineChallenge/89')
# Run('BaselineChallenge/88')
# Run('BaselineChallenge/87')
# Run('BaselineChallenge/86')
# Run('BaselineChallenge/85')
# Run('BaselineChallenge/84')
# Run('BaselineChallenge/83')
# Run('BaselineChallenge/82')
# Run('BaselineChallenge/81')
# Run('BaselineChallenge/80')
# Run('BaselineChallenge/79')
# Run('BaselineChallenge/78')
# Run('BaselineChallenge/77')
# Run('BaselineChallenge/76')
# Run('BaselineChallenge/75')
# Run('BaselineChallenge/74')
# Run('BaselineChallenge/73')
# Run('BaselineChallenge/72')
# Run('BaselineChallenge/71')
# Run('BaselineChallenge/70')
# Run('BaselineChallenge/69')
# Run('BaselineChallenge/68')
# Run('BaselineChallenge/67')
# Run('BaselineChallenge/66')
# Run('BaselineChallenge/65')
# Run('BaselineChallenge/64')
# Run('BaselineChallenge/63')
# Run('BaselineChallenge/62')
# Run('BaselineChallenge/61')
# Run('BaselineChallenge/60')
# Run('BaselineChallenge/59')
# Run('BaselineChallenge/58')
# Run('BaselineChallenge/57')
# Run('BaselineChallenge/56')
# Run('BaselineChallenge/55')
# Run('BaselineChallenge/54')
# Run('BaselineChallenge/53')
# Run('BaselineChallenge/52')
# Run('BaselineChallenge/51')
# Run('BaselineChallenge/50')
# Run('BaselineChallenge/49')
# Run('BaselineChallenge/48')
# Run('BaselineChallenge/47')
# Run('BaselineChallenge/46')
# Run('BaselineChallenge/45')

# %%
#latest run of a flow and check if its successful
latest_run = Flow('BaselineChallenge').latest_run
print(latest_run)
print(latest_run.successful)
# Out:
# Run('BaselineChallenge/97')
# True

# %%
#all steps in latest run
for step in Flow('BaselineChallenge').latest_run:
    print(step)
# Out:
# Step('BaselineChallenge/97/end')
# Step('BaselineChallenge/97/aggregate')
# Step('BaselineChallenge/97/model')
# Step('BaselineChallenge/97/baseline')
# Step('BaselineChallenge/97/start')

# %%
# list all task in a Step
for task in Step('BaselineChallenge/97/model'):
    print(task)
# Out:
# Task('BaselineChallenge/97/model/479')

# %%
for task in Step('BaselineChallenge/97/baseline'):
    print(task)
# Out:
# Task('BaselineChallenge/97/baseline/478')

# %%
# list all task in all step which failed
# TODO what is task specifically??
for step in Run('BaselineChallenge/45'):
    for task in step:
        if not task.successful:
            print("Task {} failed".format(task.pathspec))
            #print(task.stdout)
            #print(task.stderr)
# Out:
# Task BaselineChallenge/45/model/238 failed

# %%
# list all data artifacts in a Task
for dataArtifact in Task('BaselineChallenge/97/baseline/478'):
    print(dataArtifact)
# Out:
# DataArtifact('BaselineChallenge/97/baseline/478/result')
# DataArtifact('BaselineChallenge/97/baseline/478/result_serialized')
# DataArtifact('BaselineChallenge/97/baseline/478/df')
# DataArtifact('BaselineChallenge/97/baseline/478/traindf')
# DataArtifact('BaselineChallenge/97/baseline/478/valdf')
# DataArtifact('BaselineChallenge/97/baseline/478/data')
# DataArtifact('BaselineChallenge/97/baseline/478/kfold')
# DataArtifact('BaselineChallenge/97/baseline/478/name')
# DataArtifact('BaselineChallenge/97/baseline/478/scoring')
# DataArtifact('BaselineChallenge/97/baseline/478/split_size')

# %%
from metaflow import DataArtifact
from dataclasses import dataclass, fields

@dataclass
class ModelResult:
    "A custom struct for storing model evaluation results."
    name: None
    params: None
    pathspec: None
    acc: None
    rocauc: None

def classFromArgs(className, argDict):
    fieldSet = {f.name for f in fields(className) if f.init}
    filteredArgDict = {k : v for k, v in argDict.items() if k in fieldSet}
    return className(**filteredArgDict)

print(dir(Task('BaselineChallenge/97/model/479')['hyperparam_set']))
print(Task('BaselineChallenge/97/model/479')['hyperparam_set'].data)

print("________________________________")
data = Task('BaselineChallenge/97/baseline/478')['result_serialized'].data 
print(data.keys())
print(classFromArgs(ModelResult, data))
# Out:
# ['_CHILD_CLASS', '_NAME', '_PARENT_CLASS', '__class__', '__contains__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_attempt', '_created_at', '_filtered_children', '_get_child', '_get_object', '_ipython_key_completions_', '_iter_filter', '_metaflow', '_namespace_check', '_object', '_parent', '_path_components', '_pathspec', '_system_tags', '_tags', '_url_token', '_user_tags', 'created_at', 'data', 'finished_at', 'id', 'is_in_namespace', 'origin_pathspec', 'parent', 'path_components', 'pathspec', 'sha', 'size', 'system_tags', 'tags', 'user_tags']
# [{'vocab_sz': 100}, {'vocab_sz': 300}, {'vocab_sz': 500}]
# ________________________________
# dict_keys(['name', 'params', 'pathspec', 'acc', 'rocauc'])
# ModelResult(name='Baseline', params='Always predict 1', pathspec='BaselineChallenge/97/baseline/478', acc=0.7705895341134908, rocauc=0.5)

# %%
print((Task('BaselineChallenge/97/model/479')['results_serialized'].data))
print((Task('BaselineChallenge/97/baseline/478')['result_serialized'].data))
# Out:
# [{'name': 'NbowModel - vocab_sz: 100', 'params': {'vocab_sz': 100}, 'pathspec': 'BaselineChallenge/97/model/479', 'acc': 0.8180613822035769, 'rocauc': 0.8265107787684323}, {'name': 'NbowModel - vocab_sz: 300', 'params': {'vocab_sz': 300}, 'pathspec': 'BaselineChallenge/97/model/479', 'acc': 0.8567012585559726, 'rocauc': 0.8874310211218082}, {'name': 'NbowModel - vocab_sz: 500', 'params': {'vocab_sz': 500}, 'pathspec': 'BaselineChallenge/97/model/479', 'acc': 0.8507396776330316, 'rocauc': 0.888225536456423}]
# {'name': 'Baseline', 'params': 'Always predict 1', 'pathspec': 'BaselineChallenge/97/baseline/478', 'acc': 0.7705895341134908, 'rocauc': 0.5}
